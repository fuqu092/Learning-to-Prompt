# %%
import torch
import random
import numpy as np
from torchvision import datasets, transforms
from torch.utils.data.dataset import Subset
from torch.utils.data import DataLoader
from torch.utils.data import RandomSampler
from torch.utils.data import SequentialSampler
import torch.nn as nn
import timm
import torch.nn.functional as F

# %%
def get_dataloaders(input_img_size, num_classes, num_tasks, classes_per_task, batch_size, shuffle, device):
    scale = (0.05, 1.0)
    ratio = (3./4., 4./3.)
    size = int((256/224) * input_img_size)
    pin = True if device == 'cuda' else False

    transforms_train =  transforms.Compose([
        transforms.RandomResizedCrop(input_img_size, scale=scale, ratio=ratio),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.ToTensor(),
    ])

    transforms_test = transforms.Compose([
        transforms.Resize(size, interpolation=3),
        transforms.CenterCrop(input_img_size),
        transforms.ToTensor(),
    ])

    dataset_train = datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms_train)
    dataset_test = datasets.CIFAR100(root='./data', train=False, download=True, transform=transforms_test)

    split_datasets = list()
    class_mask = list()
    dataloaders_train = list()
    dataloaders_test = list()
    labels = [i for i in range(num_classes)]

    if shuffle:
        random.shuffle(labels)

    for i in range(num_tasks):
        scope = labels[:classes_per_task]
        labels = labels[classes_per_task:]

        train_split_indices = []
        test_split_indices = []

        for j in range(len(dataset_train.targets)):
            if int(dataset_train.targets[j]) in scope:
                train_split_indices.append(j)
        
        for j in range(len(dataset_test.targets)):
            if int(dataset_test.targets[j]) in scope:
                test_split_indices.append(j)

        train_subset = Subset(dataset_train, train_split_indices)
        test_subset = Subset(dataset_test, test_split_indices)

        split_datasets.append([train_subset, test_subset])
        class_mask.append(scope)

    for i in range(num_tasks):
        dataset_train_temp, dataset_test_temp = split_datasets[i]

        train_sampler = RandomSampler(dataset_train_temp)
        test_sampler = SequentialSampler(dataset_test_temp)

        dataloader_train_temp = DataLoader(dataset_train_temp, sampler=train_sampler, batch_size=batch_size, pin_memory=pin)
        dataloader_test_temp = DataLoader(dataset_test_temp, sampler=test_sampler, batch_size=batch_size, pin_memory=pin)

        dataloaders_train.append(dataloader_train_temp)
        dataloaders_test.append(dataloader_test_temp)

    return dataloaders_train, dataloaders_test, class_mask

# %%
class CustomLoss(nn.Module):
    def __init__(self, constant):
        super(CustomLoss, self).__init__()
        self.constant = constant
        self.cross_entropy = nn.CrossEntropyLoss()

    def forward(self, outputs, targets, value):
        value = value.to(outputs.device)

        ce_loss = self.cross_entropy(outputs, targets)
        cu_term = self.constant * value

        total_loss = ce_loss - cu_term

        return total_loss

# %%
class Prompt(nn.Module):
    def __init__(self, pool_size, keys_dim, prompt_dim, embed_dim, top_k):
        super(Prompt, self).__init__()
        self.pool_size = pool_size
        self.keys = nn.Parameter(torch.randn(pool_size, keys_dim)) # M x Embed_Dim
        self.prompts = nn.Parameter(torch.randn(pool_size, prompt_dim, embed_dim)) # M x Lp x Embed_Dim
        nn.init.uniform_(self.keys, -1, 1)
        nn.init.uniform_(self.prompts, -1, 1)
        self.k = top_k

    def select_prompt(self, queries): # Shape of Q (N x Embed_Dim)
        N, embed_dim = queries.shape[0], self.prompts.shape[2]

        queries_normalized = F.normalize(queries) # N x Embed_Dim
        keys_normalized = F.normalize(self.keys) # M x Embed_Dim

        cosine_similarity = torch.mm(queries_normalized, keys_normalized.T) # N x M

        _, indices = torch.topk(cosine_similarity, self.k, dim=1) # N x K

        prompt_idx, prompt_cnt = torch.unique(indices, sorted=True, return_counts=True) # 1D Tensor

        if prompt_idx.shape[0] < self.pool_size:
            min_value = torch.min(indices.flatten()).item()
            padding_size = self.pool_size - prompt_idx.shape[0]
            prompt_idx = torch.cat([prompt_idx, torch.full((padding_size,), min_value, device=prompt_idx.device)]) # 1D Tensor of size pool_size 
            prompt_cnt = torch.cat([prompt_cnt, torch.zeros((padding_size,), device=prompt_cnt.device)]) # 1D Tensor of size pool_size

        _, idx = torch.topk(prompt_cnt, self.k) # 1D Tensor of size to k

        final_indices = prompt_idx[idx].expand(N, -1) # N x K
        
        selected_prompts = self.prompts[final_indices].view(N, -1, embed_dim) # N x (K * Lp) x Embed_Dim

        selected_keys = keys_normalized[final_indices] # N x K x Embed_Dim
        queries_normalized = queries_normalized.unsqueeze(1) # N x 1 x Embed_Dim
        loss_term = selected_keys * queries_normalized # N x K x Emebd_Dim
        sum = torch.sum(loss_term) / N # 1 x 1

        return selected_prompts, sum # N x (K * Lp) x Embed_Dim and 1 x 1

# %%
class Model(nn.Module):
    def __init__(self, pool_size, prompt_dim, top_k, num_classes):
        super(Model, self).__init__()
        self.query_function = timm.create_model('vit_base_patch16_224.augreg2_in21k_ft_in1k', pretrained=True)
        self.embed_dim = self.query_function.embed_dim # 768
        self.prompt_pool = Prompt(pool_size, self.embed_dim, prompt_dim, self.embed_dim, top_k)
        self.vit = timm.create_model('vit_base_patch16_224.augreg2_in21k_ft_in1k', pretrained=True, num_classes=num_classes)
        self.pool = nn.AdaptiveAvgPool1d(1)
        self.total_prompt_dim = top_k * prompt_dim

        # Freeze the ViT model (both query_function and vit)
        for param in self.query_function.parameters():
            param.requires_grad = False
        for param in self.vit.parameters():
            param.requires_grad = False
        for param in self.vit.head.parameters():
            param.requires_grad = True

    def forward(self, x): # N x channels x H x W 
        queries = self.query_function.forward_features(x)[:, 0] # CLS Token (N x Embed_Dim)
        prompts, distance_sum = self.prompt_pool.select_prompt(queries) # N x (K * Lp) x Embed_Dim

        patch_embeddings = self.vit.patch_embed(x) # N x Token_Len x Embed_Dim
        cls_token = self.vit.cls_token.expand(patch_embeddings.shape[0], -1, -1) # N x 1 x Embed_Dim
        patch_embeddings = torch.cat((cls_token, patch_embeddings), dim=1) # N x (1 + Token_Len) x Embed_Dim
        embeddings = patch_embeddings + self.vit.pos_embed # N x (1 + Token_Len) x Embed_Dim

        tokens = torch.cat((prompts, embeddings), dim=1) # N x (K * Lp + 1 + Token_Len) x Embed_Dim

        tokens = self.vit.blocks(tokens) # N x (K * Lp + 1 + Token_Len) x Embed_Dim
        tokens = self.vit.norm(tokens)

        extracted_prompts = tokens[:, 0:self.total_prompt_dim, :] # N x K * Lp x Embed_Dim
        extracted_prompts = extracted_prompts.permute(0, 2, 1) # N x Embed_Dim x K * Lp

        pooled_prompts = self.pool(extracted_prompts).squeeze(-1) # N x Embed_Dim

        outputs = self.vit.head(pooled_prompts) # N x num_classes

        return outputs, distance_sum

# %%
INPUT_SIZE = 224
NUM_CLASSES = 100
NUM_TASKS = 10
CLASSES_PER_TASK = 10
BATCH_SIZE = 16
EPOCHS_PER_TASK = 5
LEARNING_RATE = 0.001875
POOL_SIZE = 10
PROMPT_DIM = 5
TOP_K = 5
CONSTANT = 0.1
MAX_NORM = 1.0
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
dataloaders_train, dataloaders_test, class_mask = get_dataloaders(INPUT_SIZE, NUM_CLASSES, NUM_TASKS, CLASSES_PER_TASK, BATCH_SIZE, False, device)
model = Model(POOL_SIZE, PROMPT_DIM, TOP_K, NUM_CLASSES).to(device)
criterion = CustomLoss(CONSTANT).to(device)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
print('TRAINING MODEL!!!')

model.train(True)

for i in range(NUM_TASKS):
    dataloader = dataloaders_train[i]
    mask = class_mask[i]
    total_task = 0.0
    correct_task = 0.0

    optim = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

    for j in range(EPOCHS_PER_TASK):
        total_epoch = 0.0
        correct_epoch = 0.0

        for data in dataloader:
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            logits, loss_value = model(inputs)
            loss_value = loss_value.to(device)

            not_mask = np.setdiff1d(np.arange(NUM_CLASSES), mask)
            not_mask = torch.tensor(not_mask, dtype=torch.int64).to(device)
            logits = logits.index_fill(dim=1, index=not_mask, value=float('-inf'))

            loss = criterion(logits, labels, loss_value)
            optim.zero_grad()
            nn.utils.clip_grad_norm_(model.parameters(), MAX_NORM)
            loss.backward()
            optim.step()

            _, predicted = torch.max(logits.data, 1)

            total_epoch += labels.size(0)
            correct_epoch += (predicted == labels).sum().item()

            print(f'For Task{i+1} Epoch {j+1}/{EPOCHS_PER_TASK}, Accuracy: {correct_epoch/total_epoch * 100:.2f}%')
# Out:
# TRAINING MODEL!!!
# For Task1 Epoch 1/5, Accuracy: 6.25%
# For Task1 Epoch 1/5, Accuracy: 9.38%
# For Task1 Epoch 1/5, Accuracy: 10.42%
# For Task1 Epoch 1/5, Accuracy: 14.06%
# For Task1 Epoch 1/5, Accuracy: 16.25%
# For Task1 Epoch 1/5, Accuracy: 21.88%
# For Task1 Epoch 1/5, Accuracy: 26.79%
# For Task1 Epoch 1/5, Accuracy: 28.91%
# For Task1 Epoch 1/5, Accuracy: 32.64%
# For Task1 Epoch 1/5, Accuracy: 34.38%
# For Task1 Epoch 1/5, Accuracy: 35.23%
# For Task1 Epoch 1/5, Accuracy: 35.94%
# For Task1 Epoch 1/5, Accuracy: 38.94%
# For Task1 Epoch 1/5, Accuracy: 42.86%
# For Task1 Epoch 1/5, Accuracy: 44.58%
# For Task1 Epoch 1/5, Accuracy: 47.66%
# For Task1 Epoch 1/5, Accuracy: 50.00%
# For Task1 Epoch 1/5, Accuracy: 51.74%
# For Task1 Epoch 1/5, Accuracy: 52.30%
# For Task1 Epoch 1/5, Accuracy: 52.19%
# For Task1 Epoch 1/5, Accuracy: 53.27%
# For Task1 Epoch 1/5, Accuracy: 54.83%
# For Task1 Epoch 1/5, Accuracy: 55.71%
# For Task1 Epoch 1/5, Accuracy: 57.03%
# For Task1 Epoch 1/5, Accuracy: 57.00%
# For Task1 Epoch 1/5, Accuracy: 57.69%
# For Task1 Epoch 1/5, Accuracy: 58.80%
# For Task1 Epoch 1/5, Accuracy: 59.38%
# For Task1 Epoch 1/5, Accuracy: 59.48%
# For Task1 Epoch 1/5, Accuracy: 60.21%
# For Task1 Epoch 1/5, Accuracy: 60.48%
# For Task1 Epoch 1/5, Accuracy: 60.94%
# For Task1 Epoch 1/5, Accuracy: 61.55%
# For Task1 Epoch 1/5, Accuracy: 61.58%
# For Task1 Epoch 1/5, Accuracy: 61.61%
# For Task1 Epoch 1/5, Accuracy: 62.50%
# For Task1 Epoch 1/5, Accuracy: 63.01%
# For Task1 Epoch 1/5, Accuracy: 63.32%
# For Task1 Epoch 1/5, Accuracy: 64.10%
# For Task1 Epoch 1/5, Accuracy: 64.38%
# For Task1 Epoch 1/5, Accuracy: 65.09%
# For Task1 Epoch 1/5, Accuracy: 65.77%
# For Task1 Epoch 1/5, Accuracy: 66.57%
# For Task1 Epoch 1/5, Accuracy: 67.19%
# For Task1 Epoch 1/5, Accuracy: 67.64%
# For Task1 Epoch 1/5, Accuracy: 68.21%
# For Task1 Epoch 1/5, Accuracy: 68.62%
# For Task1 Epoch 1/5, Accuracy: 69.14%
# For Task1 Epoch 1/5, Accuracy: 69.39%
# For Task1 Epoch 1/5, Accuracy: 69.75%
# For Task1 Epoch 1/5, Accuracy: 70.22%
# For Task1 Epoch 1/5, Accuracy: 70.67%
# For Task1 Epoch 1/5, Accuracy: 70.64%
# For Task1 Epoch 1/5, Accuracy: 71.06%
# For Task1 Epoch 1/5, Accuracy: 71.59%
# For Task1 Epoch 1/5, Accuracy: 71.76%
# For Task1 Epoch 1/5, Accuracy: 72.15%
# For Task1 Epoch 1/5, Accuracy: 72.41%
# For Task1 Epoch 1/5, Accuracy: 72.67%
# For Task1 Epoch 1/5, Accuracy: 72.71%
# For Task1 Epoch 1/5, Accuracy: 72.85%
# For Task1 Epoch 1/5, Accuracy: 72.58%
# For Task1 Epoch 1/5, Accuracy: 72.82%
# For Task1 Epoch 1/5, Accuracy: 72.95%
# For Task1 Epoch 1/5, Accuracy: 72.98%
# For Task1 Epoch 1/5, Accuracy: 73.39%
# For Task1 Epoch 1/5, Accuracy: 73.32%
# For Task1 Epoch 1/5, Accuracy: 73.62%
# For Task1 Epoch 1/5, Accuracy: 73.64%
# For Task1 Epoch 1/5, Accuracy: 73.93%
# For Task1 Epoch 1/5, Accuracy: 74.21%
# For Task1 Epoch 1/5, Accuracy: 74.48%
# For Task1 Epoch 1/5, Accuracy: 74.66%
# For Task1 Epoch 1/5, Accuracy: 74.83%
# For Task1 Epoch 1/5, Accuracy: 74.83%
# For Task1 Epoch 1/5, Accuracy: 75.08%
# For Task1 Epoch 1/5, Accuracy: 75.08%
# For Task1 Epoch 1/5, Accuracy: 75.40%
# For Task1 Epoch 1/5, Accuracy: 75.55%
# For Task1 Epoch 1/5, Accuracy: 75.70%
# For Task1 Epoch 1/5, Accuracy: 75.69%
# For Task1 Epoch 1/5, Accuracy: 75.84%
# For Task1 Epoch 1/5, Accuracy: 76.05%
# For Task1 Epoch 1/5, Accuracy: 76.04%
# For Task1 Epoch 1/5, Accuracy: 75.96%
# For Task1 Epoch 1/5, Accuracy: 76.16%
# For Task1 Epoch 1/5, Accuracy: 76.36%
# For Task1 Epoch 1/5, Accuracy: 76.42%
# For Task1 Epoch 1/5, Accuracy: 76.47%
# For Task1 Epoch 1/5, Accuracy: 76.60%
# For Task1 Epoch 1/5, Accuracy: 76.58%
# For Task1 Epoch 1/5, Accuracy: 76.63%
# For Task1 Epoch 1/5, Accuracy: 76.75%
# For Task1 Epoch 1/5, Accuracy: 76.93%
# For Task1 Epoch 1/5, Accuracy: 77.04%
# For Task1 Epoch 1/5, Accuracy: 77.15%
# For Task1 Epoch 1/5, Accuracy: 77.26%
# For Task1 Epoch 1/5, Accuracy: 77.30%
# For Task1 Epoch 1/5, Accuracy: 77.27%
# For Task1 Epoch 1/5, Accuracy: 77.44%
# For Task1 Epoch 1/5, Accuracy: 77.66%
# For Task1 Epoch 1/5, Accuracy: 77.70%
# For Task1 Epoch 1/5, Accuracy: 77.73%
# For Task1 Epoch 1/5, Accuracy: 77.64%
# For Task1 Epoch 1/5, Accuracy: 77.56%
# For Task1 Epoch 1/5, Accuracy: 77.48%
# For Task1 Epoch 1/5, Accuracy: 77.57%
# For Task1 Epoch 1/5, Accuracy: 77.60%
# For Task1 Epoch 1/5, Accuracy: 77.75%
# For Task1 Epoch 1/5, Accuracy: 77.90%
# For Task1 Epoch 1/5, Accuracy: 77.93%
# For Task1 Epoch 1/5, Accuracy: 77.96%
# For Task1 Epoch 1/5, Accuracy: 77.99%
# For Task1 Epoch 1/5, Accuracy: 78.07%
# For Task1 Epoch 1/5, Accuracy: 78.15%
# For Task1 Epoch 1/5, Accuracy: 78.23%
# For Task1 Epoch 1/5, Accuracy: 78.21%
# For Task1 Epoch 1/5, Accuracy: 78.28%
# For Task1 Epoch 1/5, Accuracy: 78.36%
# For Task1 Epoch 1/5, Accuracy: 78.44%
# For Task1 Epoch 1/5, Accuracy: 78.56%
# For Task1 Epoch 1/5, Accuracy: 78.69%
# For Task1 Epoch 1/5, Accuracy: 78.56%
# For Task1 Epoch 1/5, Accuracy: 78.63%
# For Task1 Epoch 1/5, Accuracy: 78.65%
# For Task1 Epoch 1/5, Accuracy: 78.62%
# For Task1 Epoch 1/5, Accuracy: 78.64%
# For Task1 Epoch 1/5, Accuracy: 78.71%
# For Task1 Epoch 1/5, Accuracy: 78.88%
# For Task1 Epoch 1/5, Accuracy: 78.89%
# For Task1 Epoch 1/5, Accuracy: 78.86%
# For Task1 Epoch 1/5, Accuracy: 79.02%
# For Task1 Epoch 1/5, Accuracy: 79.09%
# For Task1 Epoch 1/5, Accuracy: 79.01%
# For Task1 Epoch 1/5, Accuracy: 79.17%
# For Task1 Epoch 1/5, Accuracy: 79.14%
# For Task1 Epoch 1/5, Accuracy: 79.29%
# For Task1 Epoch 1/5, Accuracy: 79.30%
# For Task1 Epoch 1/5, Accuracy: 79.32%
# For Task1 Epoch 1/5, Accuracy: 79.38%
# For Task1 Epoch 1/5, Accuracy: 79.52%
# For Task1 Epoch 1/5, Accuracy: 79.45%
# For Task1 Epoch 1/5, Accuracy: 79.46%
# For Task1 Epoch 1/5, Accuracy: 79.47%
# For Task1 Epoch 1/5, Accuracy: 79.53%
# For Task1 Epoch 1/5, Accuracy: 79.49%
# For Task1 Epoch 1/5, Accuracy: 79.59%
# For Task1 Epoch 1/5, Accuracy: 79.60%
# For Task1 Epoch 1/5, Accuracy: 79.70%
# For Task1 Epoch 1/5, Accuracy: 79.83%
# For Task1 Epoch 1/5, Accuracy: 79.84%
# For Task1 Epoch 1/5, Accuracy: 79.89%
# For Task1 Epoch 1/5, Accuracy: 79.86%
# For Task1 Epoch 1/5, Accuracy: 79.83%
# For Task1 Epoch 1/5, Accuracy: 79.80%
# For Task1 Epoch 1/5, Accuracy: 79.81%
# For Task1 Epoch 1/5, Accuracy: 79.82%
# For Task1 Epoch 1/5, Accuracy: 79.79%
# For Task1 Epoch 1/5, Accuracy: 79.72%
# For Task1 Epoch 1/5, Accuracy: 79.73%
# For Task1 Epoch 1/5, Accuracy: 79.85%
# For Task1 Epoch 1/5, Accuracy: 79.82%
# For Task1 Epoch 1/5, Accuracy: 79.91%
# For Task1 Epoch 1/5, Accuracy: 79.95%
# For Task1 Epoch 1/5, Accuracy: 80.00%
# For Task1 Epoch 1/5, Accuracy: 80.12%
# For Task1 Epoch 1/5, Accuracy: 79.98%
# For Task1 Epoch 1/5, Accuracy: 79.99%
# For Task1 Epoch 1/5, Accuracy: 79.99%
# For Task1 Epoch 1/5, Accuracy: 80.00%
# For Task1 Epoch 1/5, Accuracy: 80.08%
# For Task1 Epoch 1/5, Accuracy: 80.16%
# For Task1 Epoch 1/5, Accuracy: 80.24%
# For Task1 Epoch 1/5, Accuracy: 80.28%
# For Task1 Epoch 1/5, Accuracy: 80.21%
# For Task1 Epoch 1/5, Accuracy: 80.29%
# For Task1 Epoch 1/5, Accuracy: 80.26%
# For Task1 Epoch 1/5, Accuracy: 80.27%
# For Task1 Epoch 1/5, Accuracy: 80.27%
# For Task1 Epoch 1/5, Accuracy: 80.21%
# For Task1 Epoch 1/5, Accuracy: 80.18%
# For Task1 Epoch 1/5, Accuracy: 80.12%
# For Task1 Epoch 1/5, Accuracy: 80.19%
# For Task1 Epoch 1/5, Accuracy: 80.23%
# For Task1 Epoch 1/5, Accuracy: 80.24%
# For Task1 Epoch 1/5, Accuracy: 80.28%
# For Task1 Epoch 1/5, Accuracy: 80.35%
# For Task1 Epoch 1/5, Accuracy: 80.45%
# For Task1 Epoch 1/5, Accuracy: 80.39%
# For Task1 Epoch 1/5, Accuracy: 80.33%
# For Task1 Epoch 1/5, Accuracy: 80.33%
# For Task1 Epoch 1/5, Accuracy: 80.37%
# For Task1 Epoch 1/5, Accuracy: 80.44%
# For Task1 Epoch 1/5, Accuracy: 80.44%
# For Task1 Epoch 1/5, Accuracy: 80.45%
# For Task1 Epoch 1/5, Accuracy: 80.42%
# For Task1 Epoch 1/5, Accuracy: 80.52%
# For Task1 Epoch 1/5, Accuracy: 80.62%
# For Task1 Epoch 1/5, Accuracy: 80.68%
# For Task1 Epoch 1/5, Accuracy: 80.59%
# For Task1 Epoch 1/5, Accuracy: 80.60%
# For Task1 Epoch 1/5, Accuracy: 80.66%
# For Task1 Epoch 1/5, Accuracy: 80.70%
# For Task1 Epoch 1/5, Accuracy: 80.64%
# For Task1 Epoch 1/5, Accuracy: 80.73%
# For Task1 Epoch 1/5, Accuracy: 80.79%
# For Task1 Epoch 1/5, Accuracy: 80.74%
# For Task1 Epoch 1/5, Accuracy: 80.83%
# For Task1 Epoch 1/5, Accuracy: 80.86%
# For Task1 Epoch 1/5, Accuracy: 80.92%
# For Task1 Epoch 1/5, Accuracy: 80.95%
# For Task1 Epoch 1/5, Accuracy: 81.01%
# For Task1 Epoch 1/5, Accuracy: 80.99%
# For Task1 Epoch 1/5, Accuracy: 80.93%
# For Task1 Epoch 1/5, Accuracy: 80.96%
# For Task1 Epoch 1/5, Accuracy: 81.02%
# For Task1 Epoch 1/5, Accuracy: 80.96%
# For Task1 Epoch 1/5, Accuracy: 80.99%
# For Task1 Epoch 1/5, Accuracy: 81.02%
# For Task1 Epoch 1/5, Accuracy: 81.02%
# For Task1 Epoch 1/5, Accuracy: 81.02%
# For Task1 Epoch 1/5, Accuracy: 81.05%
# For Task1 Epoch 1/5, Accuracy: 81.05%
# For Task1 Epoch 1/5, Accuracy: 81.05%
# For Task1 Epoch 1/5, Accuracy: 81.08%
# For Task1 Epoch 1/5, Accuracy: 81.06%
# For Task1 Epoch 1/5, Accuracy: 81.11%
# For Task1 Epoch 1/5, Accuracy: 81.14%
# For Task1 Epoch 1/5, Accuracy: 81.14%
# For Task1 Epoch 1/5, Accuracy: 81.17%
# For Task1 Epoch 1/5, Accuracy: 81.17%
# For Task1 Epoch 1/5, Accuracy: 81.22%
# For Task1 Epoch 1/5, Accuracy: 81.28%
# For Task1 Epoch 1/5, Accuracy: 81.22%
# For Task1 Epoch 1/5, Accuracy: 81.20%
# For Task1 Epoch 1/5, Accuracy: 81.28%
# For Task1 Epoch 1/5, Accuracy: 81.33%
# For Task1 Epoch 1/5, Accuracy: 81.33%
# For Task1 Epoch 1/5, Accuracy: 81.38%
# For Task1 Epoch 1/5, Accuracy: 81.46%
# For Task1 Epoch 1/5, Accuracy: 81.51%
# For Task1 Epoch 1/5, Accuracy: 81.56%
# For Task1 Epoch 1/5, Accuracy: 81.61%
# For Task1 Epoch 1/5, Accuracy: 81.63%
# For Task1 Epoch 1/5, Accuracy: 81.68%
# For Task1 Epoch 1/5, Accuracy: 81.71%
# For Task1 Epoch 1/5, Accuracy: 81.73%
# For Task1 Epoch 1/5, Accuracy: 81.75%
# For Task1 Epoch 1/5, Accuracy: 81.78%
# For Task1 Epoch 1/5, Accuracy: 81.75%
# For Task1 Epoch 1/5, Accuracy: 81.72%
# For Task1 Epoch 1/5, Accuracy: 81.77%
# For Task1 Epoch 1/5, Accuracy: 81.72%
# For Task1 Epoch 1/5, Accuracy: 81.74%
# For Task1 Epoch 1/5, Accuracy: 81.81%
# For Task1 Epoch 1/5, Accuracy: 81.81%
# For Task1 Epoch 1/5, Accuracy: 81.83%
# For Task1 Epoch 1/5, Accuracy: 81.83%
# For Task1 Epoch 1/5, Accuracy: 81.78%
# For Task1 Epoch 1/5, Accuracy: 81.78%
# For Task1 Epoch 1/5, Accuracy: 81.82%
# For Task1 Epoch 1/5, Accuracy: 81.87%
# For Task1 Epoch 1/5, Accuracy: 81.92%
# For Task1 Epoch 1/5, Accuracy: 81.96%
# For Task1 Epoch 1/5, Accuracy: 81.96%
# For Task1 Epoch 1/5, Accuracy: 82.00%
# For Task1 Epoch 1/5, Accuracy: 81.98%
# For Task1 Epoch 1/5, Accuracy: 82.02%
# For Task1 Epoch 1/5, Accuracy: 82.06%
# For Task1 Epoch 1/5, Accuracy: 82.11%
# For Task1 Epoch 1/5, Accuracy: 82.13%
# For Task1 Epoch 1/5, Accuracy: 82.10%
# For Task1 Epoch 1/5, Accuracy: 82.07%
# For Task1 Epoch 1/5, Accuracy: 82.12%
# For Task1 Epoch 1/5, Accuracy: 82.16%
# For Task1 Epoch 1/5, Accuracy: 82.13%
# For Task1 Epoch 1/5, Accuracy: 82.18%
# For Task1 Epoch 1/5, Accuracy: 82.10%
# For Task1 Epoch 1/5, Accuracy: 82.15%
# For Task1 Epoch 1/5, Accuracy: 82.14%
# For Task1 Epoch 1/5, Accuracy: 82.21%
# For Task1 Epoch 1/5, Accuracy: 82.23%
# For Task1 Epoch 1/5, Accuracy: 82.24%
# For Task1 Epoch 1/5, Accuracy: 82.31%
# For Task1 Epoch 1/5, Accuracy: 82.37%
# For Task1 Epoch 1/5, Accuracy: 82.41%
# For Task1 Epoch 1/5, Accuracy: 82.43%
# For Task1 Epoch 1/5, Accuracy: 82.47%
# For Task1 Epoch 1/5, Accuracy: 82.53%
# For Task1 Epoch 1/5, Accuracy: 82.56%
# For Task1 Epoch 1/5, Accuracy: 82.54%
# For Task1 Epoch 1/5, Accuracy: 82.51%
# For Task1 Epoch 1/5, Accuracy: 82.53%
# For Task1 Epoch 1/5, Accuracy: 82.57%
# For Task1 Epoch 1/5, Accuracy: 82.54%
# For Task1 Epoch 1/5, Accuracy: 82.56%
# For Task1 Epoch 1/5, Accuracy: 82.58%
# For Task1 Epoch 1/5, Accuracy: 82.63%
# For Task1 Epoch 1/5, Accuracy: 82.63%
# For Task1 Epoch 1/5, Accuracy: 82.60%
# For Task1 Epoch 1/5, Accuracy: 82.64%
# For Task1 Epoch 1/5, Accuracy: 82.66%
# For Task1 Epoch 1/5, Accuracy: 82.63%
# For Task1 Epoch 1/5, Accuracy: 82.65%
# For Task1 Epoch 1/5, Accuracy: 82.70%
# For Task1 Epoch 1/5, Accuracy: 82.74%
# For Task1 Epoch 1/5, Accuracy: 82.74%
# For Task1 Epoch 1/5, Accuracy: 82.73%
# For Task1 Epoch 1/5, Accuracy: 82.73%
# For Task1 Epoch 1/5, Accuracy: 82.76%
# For Task1 Epoch 1/5, Accuracy: 82.78%
# For Task1 Epoch 1/5, Accuracy: 82.79%
# For Task1 Epoch 1/5, Accuracy: 82.80%
# For Task1 Epoch 2/5, Accuracy: 93.75%
# For Task1 Epoch 2/5, Accuracy: 87.50%
# For Task1 Epoch 2/5, Accuracy: 87.50%
# For Task1 Epoch 2/5, Accuracy: 85.94%
# For Task1 Epoch 2/5, Accuracy: 87.50%
# For Task1 Epoch 2/5, Accuracy: 87.50%
# For Task1 Epoch 2/5, Accuracy: 89.29%
# For Task1 Epoch 2/5, Accuracy: 90.62%
# For Task1 Epoch 2/5, Accuracy: 90.28%
# For Task1 Epoch 2/5, Accuracy: 89.38%
# For Task1 Epoch 2/5, Accuracy: 89.20%
# For Task1 Epoch 2/5, Accuracy: 88.02%
# For Task1 Epoch 2/5, Accuracy: 87.50%
# For Task1 Epoch 2/5, Accuracy: 87.50%
# For Task1 Epoch 2/5, Accuracy: 87.92%
# For Task1 Epoch 2/5, Accuracy: 88.67%
# For Task1 Epoch 2/5, Accuracy: 88.60%
# For Task1 Epoch 2/5, Accuracy: 88.89%
# For Task1 Epoch 2/5, Accuracy: 88.82%
# For Task1 Epoch 2/5, Accuracy: 88.75%
# For Task1 Epoch 2/5, Accuracy: 88.69%
# For Task1 Epoch 2/5, Accuracy: 88.07%
# For Task1 Epoch 2/5, Accuracy: 87.77%
# For Task1 Epoch 2/5, Accuracy: 88.28%
# For Task1 Epoch 2/5, Accuracy: 88.00%
# For Task1 Epoch 2/5, Accuracy: 88.22%
# For Task1 Epoch 2/5, Accuracy: 88.43%
# For Task1 Epoch 2/5, Accuracy: 88.39%
# For Task1 Epoch 2/5, Accuracy: 87.93%
# For Task1 Epoch 2/5, Accuracy: 88.12%
# For Task1 Epoch 2/5, Accuracy: 88.31%
# For Task1 Epoch 2/5, Accuracy: 88.09%
# For Task1 Epoch 2/5, Accuracy: 88.07%
# For Task1 Epoch 2/5, Accuracy: 88.24%
# For Task1 Epoch 2/5, Accuracy: 88.04%
# For Task1 Epoch 2/5, Accuracy: 88.02%
# For Task1 Epoch 2/5, Accuracy: 88.34%
# For Task1 Epoch 2/5, Accuracy: 88.16%
# For Task1 Epoch 2/5, Accuracy: 87.98%
# For Task1 Epoch 2/5, Accuracy: 87.66%
# For Task1 Epoch 2/5, Accuracy: 87.96%
# For Task1 Epoch 2/5, Accuracy: 87.95%
# For Task1 Epoch 2/5, Accuracy: 87.50%
# For Task1 Epoch 2/5, Accuracy: 87.36%
# For Task1 Epoch 2/5, Accuracy: 87.36%
# For Task1 Epoch 2/5, Accuracy: 87.36%
# For Task1 Epoch 2/5, Accuracy: 87.50%
# For Task1 Epoch 2/5, Accuracy: 87.63%
# For Task1 Epoch 2/5, Accuracy: 87.76%
# For Task1 Epoch 2/5, Accuracy: 87.62%
# For Task1 Epoch 2/5, Accuracy: 87.87%
# For Task1 Epoch 2/5, Accuracy: 88.10%
# For Task1 Epoch 2/5, Accuracy: 88.09%
# For Task1 Epoch 2/5, Accuracy: 88.19%
# For Task1 Epoch 2/5, Accuracy: 88.18%
# For Task1 Epoch 2/5, Accuracy: 88.06%
# For Task1 Epoch 2/5, Accuracy: 88.05%
# For Task1 Epoch 2/5, Accuracy: 87.82%
# For Task1 Epoch 2/5, Accuracy: 88.03%
# For Task1 Epoch 2/5, Accuracy: 88.23%
# For Task1 Epoch 2/5, Accuracy: 88.32%
# For Task1 Epoch 2/5, Accuracy: 88.51%
# For Task1 Epoch 2/5, Accuracy: 88.00%
# For Task1 Epoch 2/5, Accuracy: 88.09%
# For Task1 Epoch 2/5, Accuracy: 88.08%
# For Task1 Epoch 2/5, Accuracy: 88.07%
# For Task1 Epoch 2/5, Accuracy: 87.97%
# For Task1 Epoch 2/5, Accuracy: 87.96%
# For Task1 Epoch 2/5, Accuracy: 88.04%
# For Task1 Epoch 2/5, Accuracy: 87.95%
# For Task1 Epoch 2/5, Accuracy: 87.76%
# For Task1 Epoch 2/5, Accuracy: 87.85%
# For Task1 Epoch 2/5, Accuracy: 87.84%
# For Task1 Epoch 2/5, Accuracy: 87.84%
# For Task1 Epoch 2/5, Accuracy: 87.92%
# For Task1 Epoch 2/5, Accuracy: 88.08%
# For Task1 Epoch 2/5, Accuracy: 87.99%
# For Task1 Epoch 2/5, Accuracy: 87.82%
# For Task1 Epoch 2/5, Accuracy: 87.97%
# For Task1 Epoch 2/5, Accuracy: 87.89%
# For Task1 Epoch 2/5, Accuracy: 87.96%
# For Task1 Epoch 2/5, Accuracy: 87.88%
# For Task1 Epoch 2/5, Accuracy: 87.73%
# For Task1 Epoch 2/5, Accuracy: 87.50%
# For Task1 Epoch 2/5, Accuracy: 87.65%
# For Task1 Epoch 2/5, Accuracy: 87.72%
# For Task1 Epoch 2/5, Accuracy: 87.72%
# For Task1 Epoch 2/5, Accuracy: 87.71%
# For Task1 Epoch 2/5, Accuracy: 87.57%
# For Task1 Epoch 2/5, Accuracy: 87.50%
# For Task1 Epoch 2/5, Accuracy: 87.57%
# For Task1 Epoch 2/5, Accuracy: 87.64%
# For Task1 Epoch 2/5, Accuracy: 87.70%
# For Task1 Epoch 2/5, Accuracy: 87.70%
# For Task1 Epoch 2/5, Accuracy: 87.63%
# For Task1 Epoch 2/5, Accuracy: 87.63%
# For Task1 Epoch 2/5, Accuracy: 87.56%
# For Task1 Epoch 2/5, Accuracy: 87.56%
# For Task1 Epoch 2/5, Accuracy: 87.63%
# For Task1 Epoch 2/5, Accuracy: 87.56%
# For Task1 Epoch 2/5, Accuracy: 87.62%
# For Task1 Epoch 2/5, Accuracy: 87.56%
# For Task1 Epoch 2/5, Accuracy: 87.62%
# For Task1 Epoch 2/5, Accuracy: 87.62%
# For Task1 Epoch 2/5, Accuracy: 87.68%
# For Task1 Epoch 2/5, Accuracy: 87.44%
# For Task1 Epoch 2/5, Accuracy: 87.50%
# For Task1 Epoch 2/5, Accuracy: 87.62%
# For Task1 Epoch 2/5, Accuracy: 87.67%
# For Task1 Epoch 2/5, Accuracy: 87.67%
# For Task1 Epoch 2/5, Accuracy: 87.67%
# For Task1 Epoch 2/5, Accuracy: 87.44%
# For Task1 Epoch 2/5, Accuracy: 87.50%
# For Task1 Epoch 2/5, Accuracy: 87.55%
# For Task1 Epoch 2/5, Accuracy: 87.61%
# For Task1 Epoch 2/5, Accuracy: 87.45%
# For Task1 Epoch 2/5, Accuracy: 87.39%
# For Task1 Epoch 2/5, Accuracy: 87.34%
# For Task1 Epoch 2/5, Accuracy: 87.34%
# For Task1 Epoch 2/5, Accuracy: 87.34%
# For Task1 Epoch 2/5, Accuracy: 87.35%
# For Task1 Epoch 2/5, Accuracy: 87.19%
# For Task1 Epoch 2/5, Accuracy: 87.25%
# For Task1 Epoch 2/5, Accuracy: 87.30%
# For Task1 Epoch 2/5, Accuracy: 87.20%
# For Task1 Epoch 2/5, Accuracy: 87.20%
# For Task1 Epoch 2/5, Accuracy: 87.30%
# For Task1 Epoch 2/5, Accuracy: 87.30%
# For Task1 Epoch 2/5, Accuracy: 87.31%
# For Task1 Epoch 2/5, Accuracy: 87.40%
# For Task1 Epoch 2/5, Accuracy: 87.40%
# For Task1 Epoch 2/5, Accuracy: 87.45%
# For Task1 Epoch 2/5, Accuracy: 87.50%
# For Task1 Epoch 2/5, Accuracy: 87.41%
# For Task1 Epoch 2/5, Accuracy: 87.45%
# For Task1 Epoch 2/5, Accuracy: 87.36%
# For Task1 Epoch 2/5, Accuracy: 87.32%
# For Task1 Epoch 2/5, Accuracy: 87.27%
# For Task1 Epoch 2/5, Accuracy: 87.28%
# For Task1 Epoch 2/5, Accuracy: 87.32%
# For Task1 Epoch 2/5, Accuracy: 87.32%
# For Task1 Epoch 2/5, Accuracy: 87.32%
# For Task1 Epoch 2/5, Accuracy: 87.37%
# For Task1 Epoch 2/5, Accuracy: 87.46%
# For Task1 Epoch 2/5, Accuracy: 87.46%
# For Task1 Epoch 2/5, Accuracy: 87.54%
# For Task1 Epoch 2/5, Accuracy: 87.59%
# For Task1 Epoch 2/5, Accuracy: 87.54%
# For Task1 Epoch 2/5, Accuracy: 87.58%
# For Task1 Epoch 2/5, Accuracy: 87.58%
# For Task1 Epoch 2/5, Accuracy: 87.62%
# For Task1 Epoch 2/5, Accuracy: 87.66%
# For Task1 Epoch 2/5, Accuracy: 87.70%
# For Task1 Epoch 2/5, Accuracy: 87.58%
# For Task1 Epoch 2/5, Accuracy: 87.58%
# For Task1 Epoch 2/5, Accuracy: 87.54%
# For Task1 Epoch 2/5, Accuracy: 87.50%
# For Task1 Epoch 2/5, Accuracy: 87.46%
# For Task1 Epoch 2/5, Accuracy: 87.46%
# For Task1 Epoch 2/5, Accuracy: 87.46%
# For Task1 Epoch 2/5, Accuracy: 87.42%
# For Task1 Epoch 2/5, Accuracy: 87.42%
# For Task1 Epoch 2/5, Accuracy: 87.46%
# For Task1 Epoch 2/5, Accuracy: 87.46%
# For Task1 Epoch 2/5, Accuracy: 87.54%
# For Task1 Epoch 2/5, Accuracy: 87.58%
# For Task1 Epoch 2/5, Accuracy: 87.61%
# For Task1 Epoch 2/5, Accuracy: 87.65%
# For Task1 Epoch 2/5, Accuracy: 87.65%
# For Task1 Epoch 2/5, Accuracy: 87.65%
# For Task1 Epoch 2/5, Accuracy: 87.65%
# For Task1 Epoch 2/5, Accuracy: 87.54%
# For Task1 Epoch 2/5, Accuracy: 87.57%
# For Task1 Epoch 2/5, Accuracy: 87.57%
# For Task1 Epoch 2/5, Accuracy: 87.61%
# For Task1 Epoch 2/5, Accuracy: 87.68%
# For Task1 Epoch 2/5, Accuracy: 87.71%
# For Task1 Epoch 2/5, Accuracy: 87.71%
# For Task1 Epoch 2/5, Accuracy: 87.71%
# For Task1 Epoch 2/5, Accuracy: 87.71%
# For Task1 Epoch 2/5, Accuracy: 87.71%
# For Task1 Epoch 2/5, Accuracy: 87.74%
# For Task1 Epoch 2/5, Accuracy: 87.81%
# For Task1 Epoch 2/5, Accuracy: 87.77%
# For Task1 Epoch 2/5, Accuracy: 87.80%
# For Task1 Epoch 2/5, Accuracy: 87.84%
# For Task1 Epoch 2/5, Accuracy: 87.87%
# For Task1 Epoch 2/5, Accuracy: 87.80%
# For Task1 Epoch 2/5, Accuracy: 87.80%
# For Task1 Epoch 2/5, Accuracy: 87.76%
# For Task1 Epoch 2/5, Accuracy: 87.83%
# For Task1 Epoch 2/5, Accuracy: 87.86%
# For Task1 Epoch 2/5, Accuracy: 87.76%
# For Task1 Epoch 2/5, Accuracy: 87.76%
# For Task1 Epoch 2/5, Accuracy: 87.72%
# For Task1 Epoch 2/5, Accuracy: 87.69%
# For Task1 Epoch 2/5, Accuracy: 87.69%
# For Task1 Epoch 2/5, Accuracy: 87.59%
# For Task1 Epoch 2/5, Accuracy: 87.63%
# For Task1 Epoch 2/5, Accuracy: 87.62%
# For Task1 Epoch 2/5, Accuracy: 87.66%
# For Task1 Epoch 2/5, Accuracy: 87.72%
# For Task1 Epoch 2/5, Accuracy: 87.72%
# For Task1 Epoch 2/5, Accuracy: 87.62%
# For Task1 Epoch 2/5, Accuracy: 87.62%
# For Task1 Epoch 2/5, Accuracy: 87.53%
# For Task1 Epoch 2/5, Accuracy: 87.50%
# For Task1 Epoch 2/5, Accuracy: 87.44%
# For Task1 Epoch 2/5, Accuracy: 87.38%
# For Task1 Epoch 2/5, Accuracy: 87.38%
# For Task1 Epoch 2/5, Accuracy: 87.32%
# For Task1 Epoch 2/5, Accuracy: 87.32%
# For Task1 Epoch 2/5, Accuracy: 87.35%
# For Task1 Epoch 2/5, Accuracy: 87.38%
# For Task1 Epoch 2/5, Accuracy: 87.38%
# For Task1 Epoch 2/5, Accuracy: 87.36%
# For Task1 Epoch 2/5, Accuracy: 87.33%
# For Task1 Epoch 2/5, Accuracy: 87.30%
# For Task1 Epoch 2/5, Accuracy: 87.24%
# For Task1 Epoch 2/5, Accuracy: 87.30%
# For Task1 Epoch 2/5, Accuracy: 87.25%
# For Task1 Epoch 2/5, Accuracy: 87.27%
# For Task1 Epoch 2/5, Accuracy: 87.28%
# For Task1 Epoch 2/5, Accuracy: 87.28%
# For Task1 Epoch 2/5, Accuracy: 87.28%
# For Task1 Epoch 2/5, Accuracy: 87.28%
# For Task1 Epoch 2/5, Accuracy: 87.33%
# For Task1 Epoch 2/5, Accuracy: 87.36%
# For Task1 Epoch 2/5, Accuracy: 87.36%
# For Task1 Epoch 2/5, Accuracy: 87.28%
# For Task1 Epoch 2/5, Accuracy: 87.31%
# For Task1 Epoch 2/5, Accuracy: 87.37%
# For Task1 Epoch 2/5, Accuracy: 87.39%
# For Task1 Epoch 2/5, Accuracy: 87.42%
# For Task1 Epoch 2/5, Accuracy: 87.42%
# For Task1 Epoch 2/5, Accuracy: 87.42%
# For Task1 Epoch 2/5, Accuracy: 87.47%
# For Task1 Epoch 2/5, Accuracy: 87.45%
# For Task1 Epoch 2/5, Accuracy: 87.45%
# For Task1 Epoch 2/5, Accuracy: 87.40%
# For Task1 Epoch 2/5, Accuracy: 87.32%
# For Task1 Epoch 2/5, Accuracy: 87.32%
# For Task1 Epoch 2/5, Accuracy: 87.32%
# For Task1 Epoch 2/5, Accuracy: 87.37%
# For Task1 Epoch 2/5, Accuracy: 87.37%
# For Task1 Epoch 2/5, Accuracy: 87.37%
# For Task1 Epoch 2/5, Accuracy: 87.42%
# For Task1 Epoch 2/5, Accuracy: 87.45%
# For Task1 Epoch 2/5, Accuracy: 87.42%
# For Task1 Epoch 2/5, Accuracy: 87.40%
# For Task1 Epoch 2/5, Accuracy: 87.45%
# For Task1 Epoch 2/5, Accuracy: 87.45%
# For Task1 Epoch 2/5, Accuracy: 87.43%
# For Task1 Epoch 2/5, Accuracy: 87.43%
# For Task1 Epoch 2/5, Accuracy: 87.43%
# For Task1 Epoch 2/5, Accuracy: 87.45%
# For Task1 Epoch 2/5, Accuracy: 87.45%
# For Task1 Epoch 2/5, Accuracy: 87.48%
# For Task1 Epoch 2/5, Accuracy: 87.50%
# For Task1 Epoch 2/5, Accuracy: 87.52%
# For Task1 Epoch 2/5, Accuracy: 87.55%
# For Task1 Epoch 2/5, Accuracy: 87.52%
# For Task1 Epoch 2/5, Accuracy: 87.55%
# For Task1 Epoch 2/5, Accuracy: 87.59%
# For Task1 Epoch 2/5, Accuracy: 87.59%
# For Task1 Epoch 2/5, Accuracy: 87.59%
# For Task1 Epoch 2/5, Accuracy: 87.64%
# For Task1 Epoch 2/5, Accuracy: 87.64%
# For Task1 Epoch 2/5, Accuracy: 87.64%
# For Task1 Epoch 2/5, Accuracy: 87.66%
# For Task1 Epoch 2/5, Accuracy: 87.52%
# For Task1 Epoch 2/5, Accuracy: 87.52%
# For Task1 Epoch 2/5, Accuracy: 87.55%
# For Task1 Epoch 2/5, Accuracy: 87.55%
# For Task1 Epoch 2/5, Accuracy: 87.59%
# For Task1 Epoch 2/5, Accuracy: 87.61%
# For Task1 Epoch 2/5, Accuracy: 87.66%
# For Task1 Epoch 2/5, Accuracy: 87.66%
# For Task1 Epoch 2/5, Accuracy: 87.66%
# For Task1 Epoch 2/5, Accuracy: 87.70%
# For Task1 Epoch 2/5, Accuracy: 87.72%
# For Task1 Epoch 2/5, Accuracy: 87.70%
# For Task1 Epoch 2/5, Accuracy: 87.68%
# For Task1 Epoch 2/5, Accuracy: 87.63%
# For Task1 Epoch 2/5, Accuracy: 87.65%
# For Task1 Epoch 2/5, Accuracy: 87.70%
# For Task1 Epoch 2/5, Accuracy: 87.72%
# For Task1 Epoch 2/5, Accuracy: 87.70%
# For Task1 Epoch 2/5, Accuracy: 87.69%
# For Task1 Epoch 2/5, Accuracy: 87.67%
# For Task1 Epoch 2/5, Accuracy: 87.71%
# For Task1 Epoch 2/5, Accuracy: 87.71%
# For Task1 Epoch 2/5, Accuracy: 87.73%
# For Task1 Epoch 2/5, Accuracy: 87.76%
# For Task1 Epoch 2/5, Accuracy: 87.78%
# For Task1 Epoch 2/5, Accuracy: 87.73%
# For Task1 Epoch 2/5, Accuracy: 87.75%
# For Task1 Epoch 2/5, Accuracy: 87.77%
# For Task1 Epoch 2/5, Accuracy: 87.69%
# For Task1 Epoch 2/5, Accuracy: 87.73%
# For Task1 Epoch 2/5, Accuracy: 87.77%
# For Task1 Epoch 2/5, Accuracy: 87.79%
# For Task1 Epoch 2/5, Accuracy: 87.77%
# For Task1 Epoch 2/5, Accuracy: 87.79%
# For Task1 Epoch 2/5, Accuracy: 87.81%
# For Task1 Epoch 2/5, Accuracy: 87.85%
# For Task1 Epoch 2/5, Accuracy: 87.83%
# For Task1 Epoch 2/5, Accuracy: 87.82%
# For Task1 Epoch 2/5, Accuracy: 87.80%
# For Task1 Epoch 2/5, Accuracy: 87.80%
# For Task1 Epoch 2/5, Accuracy: 87.74%
# For Task1 Epoch 2/5, Accuracy: 87.76%
# For Task1 Epoch 2/5, Accuracy: 87.74%
# For Task1 Epoch 3/5, Accuracy: 93.75%
# For Task1 Epoch 3/5, Accuracy: 96.88%
# For Task1 Epoch 3/5, Accuracy: 97.92%
# For Task1 Epoch 3/5, Accuracy: 95.31%
# For Task1 Epoch 3/5, Accuracy: 95.00%
# For Task1 Epoch 3/5, Accuracy: 95.83%
# For Task1 Epoch 3/5, Accuracy: 95.54%
# For Task1 Epoch 3/5, Accuracy: 95.31%
# For Task1 Epoch 3/5, Accuracy: 94.44%
# For Task1 Epoch 3/5, Accuracy: 93.75%
# For Task1 Epoch 3/5, Accuracy: 94.32%
# For Task1 Epoch 3/5, Accuracy: 93.23%
# For Task1 Epoch 3/5, Accuracy: 92.31%
# For Task1 Epoch 3/5, Accuracy: 92.41%
# For Task1 Epoch 3/5, Accuracy: 91.67%
# For Task1 Epoch 3/5, Accuracy: 91.02%
# For Task1 Epoch 3/5, Accuracy: 91.18%
# For Task1 Epoch 3/5, Accuracy: 90.97%
# For Task1 Epoch 3/5, Accuracy: 90.46%
# For Task1 Epoch 3/5, Accuracy: 90.62%
# For Task1 Epoch 3/5, Accuracy: 90.77%
# For Task1 Epoch 3/5, Accuracy: 90.62%
# For Task1 Epoch 3/5, Accuracy: 90.76%
# For Task1 Epoch 3/5, Accuracy: 90.36%
# For Task1 Epoch 3/5, Accuracy: 89.50%
# For Task1 Epoch 3/5, Accuracy: 89.42%
# For Task1 Epoch 3/5, Accuracy: 89.81%
# For Task1 Epoch 3/5, Accuracy: 89.51%
# For Task1 Epoch 3/5, Accuracy: 89.66%
# For Task1 Epoch 3/5, Accuracy: 89.58%
# For Task1 Epoch 3/5, Accuracy: 89.72%
# For Task1 Epoch 3/5, Accuracy: 89.65%
# For Task1 Epoch 3/5, Accuracy: 89.39%
# For Task1 Epoch 3/5, Accuracy: 89.34%
# For Task1 Epoch 3/5, Accuracy: 89.11%
# For Task1 Epoch 3/5, Accuracy: 89.06%
# For Task1 Epoch 3/5, Accuracy: 89.02%
# For Task1 Epoch 3/5, Accuracy: 88.98%
# For Task1 Epoch 3/5, Accuracy: 89.26%
# For Task1 Epoch 3/5, Accuracy: 89.38%
# For Task1 Epoch 3/5, Accuracy: 89.18%
# For Task1 Epoch 3/5, Accuracy: 88.99%
# For Task1 Epoch 3/5, Accuracy: 89.24%
# For Task1 Epoch 3/5, Accuracy: 89.20%
# For Task1 Epoch 3/5, Accuracy: 89.17%
# For Task1 Epoch 3/5, Accuracy: 88.86%
# For Task1 Epoch 3/5, Accuracy: 88.70%
# For Task1 Epoch 3/5, Accuracy: 88.80%
# For Task1 Epoch 3/5, Accuracy: 88.78%
# For Task1 Epoch 3/5, Accuracy: 88.75%
# For Task1 Epoch 3/5, Accuracy: 88.73%
# For Task1 Epoch 3/5, Accuracy: 88.82%
# For Task1 Epoch 3/5, Accuracy: 88.92%
# For Task1 Epoch 3/5, Accuracy: 89.00%
# For Task1 Epoch 3/5, Accuracy: 89.09%
# For Task1 Epoch 3/5, Accuracy: 89.06%
# For Task1 Epoch 3/5, Accuracy: 88.93%
# For Task1 Epoch 3/5, Accuracy: 88.90%
# For Task1 Epoch 3/5, Accuracy: 88.88%
# For Task1 Epoch 3/5, Accuracy: 88.96%
# For Task1 Epoch 3/5, Accuracy: 89.04%
# For Task1 Epoch 3/5, Accuracy: 89.01%
# For Task1 Epoch 3/5, Accuracy: 88.79%
# For Task1 Epoch 3/5, Accuracy: 88.77%
# For Task1 Epoch 3/5, Accuracy: 88.75%
# For Task1 Epoch 3/5, Accuracy: 88.73%
# For Task1 Epoch 3/5, Accuracy: 88.71%
# For Task1 Epoch 3/5, Accuracy: 88.79%
# For Task1 Epoch 3/5, Accuracy: 88.59%
# For Task1 Epoch 3/5, Accuracy: 88.57%
# For Task1 Epoch 3/5, Accuracy: 88.56%
# For Task1 Epoch 3/5, Accuracy: 88.63%
# For Task1 Epoch 3/5, Accuracy: 88.53%
# For Task1 Epoch 3/5, Accuracy: 88.51%
# For Task1 Epoch 3/5, Accuracy: 88.58%
# For Task1 Epoch 3/5, Accuracy: 88.73%
# For Task1 Epoch 3/5, Accuracy: 88.72%
# For Task1 Epoch 3/5, Accuracy: 88.86%
# For Task1 Epoch 3/5, Accuracy: 88.77%
# For Task1 Epoch 3/5, Accuracy: 88.83%
# For Task1 Epoch 3/5, Accuracy: 88.81%
# For Task1 Epoch 3/5, Accuracy: 88.72%
# For Task1 Epoch 3/5, Accuracy: 88.78%
# For Task1 Epoch 3/5, Accuracy: 88.69%
# For Task1 Epoch 3/5, Accuracy: 88.68%
# For Task1 Epoch 3/5, Accuracy: 88.74%
# For Task1 Epoch 3/5, Accuracy: 88.65%
# For Task1 Epoch 3/5, Accuracy: 88.71%
# For Task1 Epoch 3/5, Accuracy: 88.69%
# For Task1 Epoch 3/5, Accuracy: 88.75%
# For Task1 Epoch 3/5, Accuracy: 88.67%
# For Task1 Epoch 3/5, Accuracy: 88.79%
# For Task1 Epoch 3/5, Accuracy: 88.84%
# For Task1 Epoch 3/5, Accuracy: 88.76%
# For Task1 Epoch 3/5, Accuracy: 88.88%
# For Task1 Epoch 3/5, Accuracy: 88.80%
# For Task1 Epoch 3/5, Accuracy: 88.85%
# For Task1 Epoch 3/5, Accuracy: 88.97%
# For Task1 Epoch 3/5, Accuracy: 89.02%
# For Task1 Epoch 3/5, Accuracy: 89.12%
# For Task1 Epoch 3/5, Accuracy: 88.99%
# For Task1 Epoch 3/5, Accuracy: 89.09%
# For Task1 Epoch 3/5, Accuracy: 88.96%
# For Task1 Epoch 3/5, Accuracy: 88.88%
# For Task1 Epoch 3/5, Accuracy: 88.87%
# For Task1 Epoch 3/5, Accuracy: 88.97%
# For Task1 Epoch 3/5, Accuracy: 89.02%
# For Task1 Epoch 3/5, Accuracy: 89.12%
# For Task1 Epoch 3/5, Accuracy: 89.16%
# For Task1 Epoch 3/5, Accuracy: 89.09%
# For Task1 Epoch 3/5, Accuracy: 89.02%
# For Task1 Epoch 3/5, Accuracy: 88.95%
# For Task1 Epoch 3/5, Accuracy: 88.99%
# For Task1 Epoch 3/5, Accuracy: 88.93%
# For Task1 Epoch 3/5, Accuracy: 88.80%
# For Task1 Epoch 3/5, Accuracy: 88.74%
# For Task1 Epoch 3/5, Accuracy: 88.68%
# For Task1 Epoch 3/5, Accuracy: 88.72%
# For Task1 Epoch 3/5, Accuracy: 88.66%
# For Task1 Epoch 3/5, Accuracy: 88.65%
# For Task1 Epoch 3/5, Accuracy: 88.69%
# For Task1 Epoch 3/5, Accuracy: 88.68%
# For Task1 Epoch 3/5, Accuracy: 88.77%
# For Task1 Epoch 3/5, Accuracy: 88.76%
# For Task1 Epoch 3/5, Accuracy: 88.75%
# For Task1 Epoch 3/5, Accuracy: 88.74%
# For Task1 Epoch 3/5, Accuracy: 88.78%
# For Task1 Epoch 3/5, Accuracy: 88.72%
# For Task1 Epoch 3/5, Accuracy: 88.71%
# For Task1 Epoch 3/5, Accuracy: 88.70%
# For Task1 Epoch 3/5, Accuracy: 88.74%
# For Task1 Epoch 3/5, Accuracy: 88.83%
# For Task1 Epoch 3/5, Accuracy: 88.82%
# For Task1 Epoch 3/5, Accuracy: 88.81%
# For Task1 Epoch 3/5, Accuracy: 88.89%
# For Task1 Epoch 3/5, Accuracy: 88.92%
# For Task1 Epoch 3/5, Accuracy: 89.01%
# For Task1 Epoch 3/5, Accuracy: 89.09%
# For Task1 Epoch 3/5, Accuracy: 89.03%
# For Task1 Epoch 3/5, Accuracy: 88.88%
# For Task1 Epoch 3/5, Accuracy: 88.83%
# For Task1 Epoch 3/5, Accuracy: 88.86%
# For Task1 Epoch 3/5, Accuracy: 88.77%
# For Task1 Epoch 3/5, Accuracy: 88.85%
# For Task1 Epoch 3/5, Accuracy: 88.88%
# For Task1 Epoch 3/5, Accuracy: 88.83%
# For Task1 Epoch 3/5, Accuracy: 88.82%
# For Task1 Epoch 3/5, Accuracy: 88.89%
# For Task1 Epoch 3/5, Accuracy: 88.97%
# For Task1 Epoch 3/5, Accuracy: 88.96%
# For Task1 Epoch 3/5, Accuracy: 89.03%
# For Task1 Epoch 3/5, Accuracy: 89.02%
# For Task1 Epoch 3/5, Accuracy: 89.01%
# For Task1 Epoch 3/5, Accuracy: 88.92%
# For Task1 Epoch 3/5, Accuracy: 88.91%
# For Task1 Epoch 3/5, Accuracy: 88.94%
# For Task1 Epoch 3/5, Accuracy: 88.97%
# For Task1 Epoch 3/5, Accuracy: 89.04%
# For Task1 Epoch 3/5, Accuracy: 89.03%
# For Task1 Epoch 3/5, Accuracy: 89.02%
# For Task1 Epoch 3/5, Accuracy: 89.01%
# For Task1 Epoch 3/5, Accuracy: 89.04%
# For Task1 Epoch 3/5, Accuracy: 89.03%
# For Task1 Epoch 3/5, Accuracy: 89.10%
# For Task1 Epoch 3/5, Accuracy: 89.17%
# For Task1 Epoch 3/5, Accuracy: 89.12%
# For Task1 Epoch 3/5, Accuracy: 89.07%
# For Task1 Epoch 3/5, Accuracy: 89.06%
# For Task1 Epoch 3/5, Accuracy: 89.13%
# For Task1 Epoch 3/5, Accuracy: 89.19%
# For Task1 Epoch 3/5, Accuracy: 89.18%
# For Task1 Epoch 3/5, Accuracy: 89.14%
# For Task1 Epoch 3/5, Accuracy: 89.09%
# For Task1 Epoch 3/5, Accuracy: 89.04%
# For Task1 Epoch 3/5, Accuracy: 89.00%
# For Task1 Epoch 3/5, Accuracy: 89.06%
# For Task1 Epoch 3/5, Accuracy: 89.12%
# For Task1 Epoch 3/5, Accuracy: 89.12%
# For Task1 Epoch 3/5, Accuracy: 89.04%
# For Task1 Epoch 3/5, Accuracy: 89.03%
# For Task1 Epoch 3/5, Accuracy: 88.98%
# For Task1 Epoch 3/5, Accuracy: 89.05%
# For Task1 Epoch 3/5, Accuracy: 89.07%
# For Task1 Epoch 3/5, Accuracy: 89.06%
# For Task1 Epoch 3/5, Accuracy: 89.12%
# For Task1 Epoch 3/5, Accuracy: 89.15%
# For Task1 Epoch 3/5, Accuracy: 89.14%
# For Task1 Epoch 3/5, Accuracy: 89.10%
# For Task1 Epoch 3/5, Accuracy: 89.09%
# For Task1 Epoch 3/5, Accuracy: 89.08%
# For Task1 Epoch 3/5, Accuracy: 89.10%
# For Task1 Epoch 3/5, Accuracy: 89.03%
# For Task1 Epoch 3/5, Accuracy: 89.09%
# For Task1 Epoch 3/5, Accuracy: 89.08%
# For Task1 Epoch 3/5, Accuracy: 89.07%
# For Task1 Epoch 3/5, Accuracy: 88.90%
# For Task1 Epoch 3/5, Accuracy: 88.90%
# For Task1 Epoch 3/5, Accuracy: 88.92%
# For Task1 Epoch 3/5, Accuracy: 88.91%
# For Task1 Epoch 3/5, Accuracy: 88.97%
# For Task1 Epoch 3/5, Accuracy: 88.96%
# For Task1 Epoch 3/5, Accuracy: 88.92%
# For Task1 Epoch 3/5, Accuracy: 88.89%
# For Task1 Epoch 3/5, Accuracy: 88.85%
# For Task1 Epoch 3/5, Accuracy: 88.84%
# For Task1 Epoch 3/5, Accuracy: 88.87%
# For Task1 Epoch 3/5, Accuracy: 88.92%
# For Task1 Epoch 3/5, Accuracy: 88.94%
# For Task1 Epoch 3/5, Accuracy: 89.00%
# For Task1 Epoch 3/5, Accuracy: 88.99%
# For Task1 Epoch 3/5, Accuracy: 88.98%
# For Task1 Epoch 3/5, Accuracy: 88.97%
# For Task1 Epoch 3/5, Accuracy: 88.97%
# For Task1 Epoch 3/5, Accuracy: 88.93%
# For Task1 Epoch 3/5, Accuracy: 88.90%
# For Task1 Epoch 3/5, Accuracy: 88.95%
# For Task1 Epoch 3/5, Accuracy: 88.94%
# For Task1 Epoch 3/5, Accuracy: 88.99%
# For Task1 Epoch 3/5, Accuracy: 88.93%
# For Task1 Epoch 3/5, Accuracy: 88.92%
# For Task1 Epoch 3/5, Accuracy: 88.89%
# For Task1 Epoch 3/5, Accuracy: 88.85%
# For Task1 Epoch 3/5, Accuracy: 88.85%
# For Task1 Epoch 3/5, Accuracy: 88.84%
# For Task1 Epoch 3/5, Accuracy: 88.89%
# For Task1 Epoch 3/5, Accuracy: 88.91%
# For Task1 Epoch 3/5, Accuracy: 88.93%
# For Task1 Epoch 3/5, Accuracy: 88.90%
# For Task1 Epoch 3/5, Accuracy: 88.89%
# For Task1 Epoch 3/5, Accuracy: 88.91%
# For Task1 Epoch 3/5, Accuracy: 88.85%
# For Task1 Epoch 3/5, Accuracy: 88.90%
# For Task1 Epoch 3/5, Accuracy: 88.89%
# For Task1 Epoch 3/5, Accuracy: 88.86%
# For Task1 Epoch 3/5, Accuracy: 88.83%
# For Task1 Epoch 3/5, Accuracy: 88.88%
# For Task1 Epoch 3/5, Accuracy: 88.92%
# For Task1 Epoch 3/5, Accuracy: 88.94%
# For Task1 Epoch 3/5, Accuracy: 88.94%
# For Task1 Epoch 3/5, Accuracy: 88.96%
# For Task1 Epoch 3/5, Accuracy: 88.90%
# For Task1 Epoch 3/5, Accuracy: 88.89%
# For Task1 Epoch 3/5, Accuracy: 88.91%
# For Task1 Epoch 3/5, Accuracy: 88.83%
# For Task1 Epoch 3/5, Accuracy: 88.83%
# For Task1 Epoch 3/5, Accuracy: 88.77%
# For Task1 Epoch 3/5, Accuracy: 88.79%
# For Task1 Epoch 3/5, Accuracy: 88.81%
# For Task1 Epoch 3/5, Accuracy: 88.76%
# For Task1 Epoch 3/5, Accuracy: 88.70%
# For Task1 Epoch 3/5, Accuracy: 88.70%
# For Task1 Epoch 3/5, Accuracy: 88.72%
# For Task1 Epoch 3/5, Accuracy: 88.74%
# For Task1 Epoch 3/5, Accuracy: 88.73%
# For Task1 Epoch 3/5, Accuracy: 88.73%
# For Task1 Epoch 3/5, Accuracy: 88.77%
# For Task1 Epoch 3/5, Accuracy: 88.74%
# For Task1 Epoch 3/5, Accuracy: 88.76%
# For Task1 Epoch 3/5, Accuracy: 88.80%
# For Task1 Epoch 3/5, Accuracy: 88.82%
# For Task1 Epoch 3/5, Accuracy: 88.79%
# For Task1 Epoch 3/5, Accuracy: 88.81%
# For Task1 Epoch 3/5, Accuracy: 88.78%
# For Task1 Epoch 3/5, Accuracy: 88.73%
# For Task1 Epoch 3/5, Accuracy: 88.75%
# For Task1 Epoch 3/5, Accuracy: 88.75%
# For Task1 Epoch 3/5, Accuracy: 88.76%
# For Task1 Epoch 3/5, Accuracy: 88.81%
# For Task1 Epoch 3/5, Accuracy: 88.80%
# For Task1 Epoch 3/5, Accuracy: 88.82%
# For Task1 Epoch 3/5, Accuracy: 88.79%
# For Task1 Epoch 3/5, Accuracy: 88.79%
# For Task1 Epoch 3/5, Accuracy: 88.80%
# For Task1 Epoch 3/5, Accuracy: 88.75%
# For Task1 Epoch 3/5, Accuracy: 88.75%
# For Task1 Epoch 3/5, Accuracy: 88.77%
# For Task1 Epoch 3/5, Accuracy: 88.79%
# For Task1 Epoch 3/5, Accuracy: 88.78%
# For Task1 Epoch 3/5, Accuracy: 88.78%
# For Task1 Epoch 3/5, Accuracy: 88.79%
# For Task1 Epoch 3/5, Accuracy: 88.77%
# For Task1 Epoch 3/5, Accuracy: 88.72%
# For Task1 Epoch 3/5, Accuracy: 88.74%
# For Task1 Epoch 3/5, Accuracy: 88.78%
# For Task1 Epoch 3/5, Accuracy: 88.79%
# For Task1 Epoch 3/5, Accuracy: 88.83%
# For Task1 Epoch 3/5, Accuracy: 88.87%
# For Task1 Epoch 3/5, Accuracy: 88.91%
# For Task1 Epoch 3/5, Accuracy: 88.91%
# For Task1 Epoch 3/5, Accuracy: 88.88%
# For Task1 Epoch 3/5, Accuracy: 88.92%
# For Task1 Epoch 3/5, Accuracy: 88.91%
# For Task1 Epoch 3/5, Accuracy: 88.93%
# For Task1 Epoch 3/5, Accuracy: 88.88%
# For Task1 Epoch 3/5, Accuracy: 88.92%
# For Task1 Epoch 3/5, Accuracy: 88.87%
# For Task1 Epoch 3/5, Accuracy: 88.87%
# For Task1 Epoch 3/5, Accuracy: 88.91%
# For Task1 Epoch 3/5, Accuracy: 88.84%
# For Task1 Epoch 3/5, Accuracy: 88.77%
# For Task1 Epoch 3/5, Accuracy: 88.75%
# For Task1 Epoch 3/5, Accuracy: 88.78%
# For Task1 Epoch 3/5, Accuracy: 88.82%
# For Task1 Epoch 3/5, Accuracy: 88.82%
# For Task1 Epoch 3/5, Accuracy: 88.83%
# For Task1 Epoch 3/5, Accuracy: 88.83%
# For Task1 Epoch 3/5, Accuracy: 88.82%
# For Task1 Epoch 3/5, Accuracy: 88.84%
# For Task1 Epoch 3/5, Accuracy: 88.86%
# For Task1 Epoch 3/5, Accuracy: 88.85%
# For Task1 Epoch 3/5, Accuracy: 88.83%
# For Task1 Epoch 3/5, Accuracy: 88.86%
# For Task1 Epoch 3/5, Accuracy: 88.84%
# For Task1 Epoch 4/5, Accuracy: 93.75%
# For Task1 Epoch 4/5, Accuracy: 84.38%
# For Task1 Epoch 4/5, Accuracy: 85.42%
# For Task1 Epoch 4/5, Accuracy: 87.50%
# For Task1 Epoch 4/5, Accuracy: 90.00%
# For Task1 Epoch 4/5, Accuracy: 91.67%
# For Task1 Epoch 4/5, Accuracy: 90.18%
# For Task1 Epoch 4/5, Accuracy: 90.62%
# For Task1 Epoch 4/5, Accuracy: 88.89%
# For Task1 Epoch 4/5, Accuracy: 89.38%
# For Task1 Epoch 4/5, Accuracy: 88.64%
# For Task1 Epoch 4/5, Accuracy: 89.58%
# For Task1 Epoch 4/5, Accuracy: 89.90%
# For Task1 Epoch 4/5, Accuracy: 90.18%
# For Task1 Epoch 4/5, Accuracy: 90.00%
# For Task1 Epoch 4/5, Accuracy: 90.62%
# For Task1 Epoch 4/5, Accuracy: 90.81%
# For Task1 Epoch 4/5, Accuracy: 91.32%
# For Task1 Epoch 4/5, Accuracy: 91.78%
# For Task1 Epoch 4/5, Accuracy: 91.88%
# For Task1 Epoch 4/5, Accuracy: 90.77%
# For Task1 Epoch 4/5, Accuracy: 90.91%
# For Task1 Epoch 4/5, Accuracy: 90.22%
# For Task1 Epoch 4/5, Accuracy: 90.36%
# For Task1 Epoch 4/5, Accuracy: 90.75%
# For Task1 Epoch 4/5, Accuracy: 90.62%
# For Task1 Epoch 4/5, Accuracy: 90.51%
# For Task1 Epoch 4/5, Accuracy: 90.40%
# For Task1 Epoch 4/5, Accuracy: 90.52%
# For Task1 Epoch 4/5, Accuracy: 90.62%
# For Task1 Epoch 4/5, Accuracy: 90.93%
# For Task1 Epoch 4/5, Accuracy: 90.82%
# For Task1 Epoch 4/5, Accuracy: 91.10%
# For Task1 Epoch 4/5, Accuracy: 91.18%
# For Task1 Epoch 4/5, Accuracy: 91.25%
# For Task1 Epoch 4/5, Accuracy: 91.15%
# For Task1 Epoch 4/5, Accuracy: 91.22%
# For Task1 Epoch 4/5, Accuracy: 91.12%
# For Task1 Epoch 4/5, Accuracy: 91.03%
# For Task1 Epoch 4/5, Accuracy: 90.94%
# For Task1 Epoch 4/5, Accuracy: 91.01%
# For Task1 Epoch 4/5, Accuracy: 91.07%
# For Task1 Epoch 4/5, Accuracy: 90.99%
# For Task1 Epoch 4/5, Accuracy: 90.91%
# For Task1 Epoch 4/5, Accuracy: 90.83%
# For Task1 Epoch 4/5, Accuracy: 90.90%
# For Task1 Epoch 4/5, Accuracy: 90.96%
# For Task1 Epoch 4/5, Accuracy: 90.76%
# For Task1 Epoch 4/5, Accuracy: 90.94%
# For Task1 Epoch 4/5, Accuracy: 90.75%
# For Task1 Epoch 4/5, Accuracy: 90.93%
# For Task1 Epoch 4/5, Accuracy: 90.99%
# For Task1 Epoch 4/5, Accuracy: 90.68%
# For Task1 Epoch 4/5, Accuracy: 90.39%
# For Task1 Epoch 4/5, Accuracy: 90.45%
# For Task1 Epoch 4/5, Accuracy: 90.40%
# For Task1 Epoch 4/5, Accuracy: 90.35%
# For Task1 Epoch 4/5, Accuracy: 90.30%
# For Task1 Epoch 4/5, Accuracy: 90.25%
# For Task1 Epoch 4/5, Accuracy: 90.31%
# For Task1 Epoch 4/5, Accuracy: 90.37%
# For Task1 Epoch 4/5, Accuracy: 90.42%
# For Task1 Epoch 4/5, Accuracy: 90.38%
# For Task1 Epoch 4/5, Accuracy: 90.23%
# For Task1 Epoch 4/5, Accuracy: 90.19%
# For Task1 Epoch 4/5, Accuracy: 90.34%
# For Task1 Epoch 4/5, Accuracy: 90.49%
# For Task1 Epoch 4/5, Accuracy: 90.44%
# For Task1 Epoch 4/5, Accuracy: 90.31%
# For Task1 Epoch 4/5, Accuracy: 90.36%
# For Task1 Epoch 4/5, Accuracy: 90.23%
# For Task1 Epoch 4/5, Accuracy: 90.28%
# For Task1 Epoch 4/5, Accuracy: 90.33%
# For Task1 Epoch 4/5, Accuracy: 90.37%
# For Task1 Epoch 4/5, Accuracy: 90.17%
# For Task1 Epoch 4/5, Accuracy: 90.13%
# For Task1 Epoch 4/5, Accuracy: 90.10%
# For Task1 Epoch 4/5, Accuracy: 90.22%
# For Task1 Epoch 4/5, Accuracy: 90.27%
# For Task1 Epoch 4/5, Accuracy: 90.31%
# For Task1 Epoch 4/5, Accuracy: 90.28%
# For Task1 Epoch 4/5, Accuracy: 90.32%
# For Task1 Epoch 4/5, Accuracy: 90.36%
# For Task1 Epoch 4/5, Accuracy: 90.40%
# For Task1 Epoch 4/5, Accuracy: 90.51%
# For Task1 Epoch 4/5, Accuracy: 90.55%
# For Task1 Epoch 4/5, Accuracy: 90.66%
# For Task1 Epoch 4/5, Accuracy: 90.70%
# For Task1 Epoch 4/5, Accuracy: 90.73%
# For Task1 Epoch 4/5, Accuracy: 90.76%
# For Task1 Epoch 4/5, Accuracy: 90.87%
# For Task1 Epoch 4/5, Accuracy: 90.96%
# For Task1 Epoch 4/5, Accuracy: 90.99%
# For Task1 Epoch 4/5, Accuracy: 90.96%
# For Task1 Epoch 4/5, Accuracy: 90.99%
# For Task1 Epoch 4/5, Accuracy: 90.89%
# For Task1 Epoch 4/5, Accuracy: 90.85%
# For Task1 Epoch 4/5, Accuracy: 90.88%
# For Task1 Epoch 4/5, Accuracy: 90.72%
# For Task1 Epoch 4/5, Accuracy: 90.69%
# For Task1 Epoch 4/5, Accuracy: 90.59%
# For Task1 Epoch 4/5, Accuracy: 90.62%
# For Task1 Epoch 4/5, Accuracy: 90.59%
# For Task1 Epoch 4/5, Accuracy: 90.56%
# For Task1 Epoch 4/5, Accuracy: 90.60%
# For Task1 Epoch 4/5, Accuracy: 90.51%
# For Task1 Epoch 4/5, Accuracy: 90.42%
# For Task1 Epoch 4/5, Accuracy: 90.22%
# For Task1 Epoch 4/5, Accuracy: 90.14%
# For Task1 Epoch 4/5, Accuracy: 90.17%
# For Task1 Epoch 4/5, Accuracy: 90.26%
# For Task1 Epoch 4/5, Accuracy: 90.23%
# For Task1 Epoch 4/5, Accuracy: 90.21%
# For Task1 Epoch 4/5, Accuracy: 90.24%
# For Task1 Epoch 4/5, Accuracy: 90.16%
# For Task1 Epoch 4/5, Accuracy: 90.09%
# For Task1 Epoch 4/5, Accuracy: 90.12%
# For Task1 Epoch 4/5, Accuracy: 90.10%
# For Task1 Epoch 4/5, Accuracy: 89.97%
# For Task1 Epoch 4/5, Accuracy: 90.00%
# For Task1 Epoch 4/5, Accuracy: 90.03%
# For Task1 Epoch 4/5, Accuracy: 90.01%
# For Task1 Epoch 4/5, Accuracy: 90.04%
# For Task1 Epoch 4/5, Accuracy: 89.97%
# For Task1 Epoch 4/5, Accuracy: 90.05%
# For Task1 Epoch 4/5, Accuracy: 90.13%
# For Task1 Epoch 4/5, Accuracy: 90.11%
# For Task1 Epoch 4/5, Accuracy: 90.04%
# For Task1 Epoch 4/5, Accuracy: 90.02%
# For Task1 Epoch 4/5, Accuracy: 90.00%
# For Task1 Epoch 4/5, Accuracy: 90.03%
# For Task1 Epoch 4/5, Accuracy: 90.06%
# For Task1 Epoch 4/5, Accuracy: 90.04%
# For Task1 Epoch 4/5, Accuracy: 90.07%
# For Task1 Epoch 4/5, Accuracy: 90.09%
# For Task1 Epoch 4/5, Accuracy: 89.98%
# For Task1 Epoch 4/5, Accuracy: 89.96%
# For Task1 Epoch 4/5, Accuracy: 89.86%
# For Task1 Epoch 4/5, Accuracy: 89.88%
# For Task1 Epoch 4/5, Accuracy: 89.78%
# For Task1 Epoch 4/5, Accuracy: 89.72%
# For Task1 Epoch 4/5, Accuracy: 89.70%
# For Task1 Epoch 4/5, Accuracy: 89.64%
# For Task1 Epoch 4/5, Accuracy: 89.71%
# For Task1 Epoch 4/5, Accuracy: 89.74%
# For Task1 Epoch 4/5, Accuracy: 89.68%
# For Task1 Epoch 4/5, Accuracy: 89.63%
# For Task1 Epoch 4/5, Accuracy: 89.70%
# For Task1 Epoch 4/5, Accuracy: 89.72%
# For Task1 Epoch 4/5, Accuracy: 89.67%
# For Task1 Epoch 4/5, Accuracy: 89.57%
# For Task1 Epoch 4/5, Accuracy: 89.51%
# For Task1 Epoch 4/5, Accuracy: 89.50%
# For Task1 Epoch 4/5, Accuracy: 89.57%
# For Task1 Epoch 4/5, Accuracy: 89.56%
# For Task1 Epoch 4/5, Accuracy: 89.62%
# For Task1 Epoch 4/5, Accuracy: 89.57%
# For Task1 Epoch 4/5, Accuracy: 89.60%
# For Task1 Epoch 4/5, Accuracy: 89.58%
# For Task1 Epoch 4/5, Accuracy: 89.61%
# For Task1 Epoch 4/5, Accuracy: 89.64%
# For Task1 Epoch 4/5, Accuracy: 89.58%
# For Task1 Epoch 4/5, Accuracy: 89.57%
# For Task1 Epoch 4/5, Accuracy: 89.60%
# For Task1 Epoch 4/5, Accuracy: 89.58%
# For Task1 Epoch 4/5, Accuracy: 89.57%
# For Task1 Epoch 4/5, Accuracy: 89.60%
# For Task1 Epoch 4/5, Accuracy: 89.62%
# For Task1 Epoch 4/5, Accuracy: 89.61%
# For Task1 Epoch 4/5, Accuracy: 89.63%
# For Task1 Epoch 4/5, Accuracy: 89.58%
# For Task1 Epoch 4/5, Accuracy: 89.64%
# For Task1 Epoch 4/5, Accuracy: 89.60%
# For Task1 Epoch 4/5, Accuracy: 89.66%
# For Task1 Epoch 4/5, Accuracy: 89.64%
# For Task1 Epoch 4/5, Accuracy: 89.56%
# For Task1 Epoch 4/5, Accuracy: 89.55%
# For Task1 Epoch 4/5, Accuracy: 89.61%
# For Task1 Epoch 4/5, Accuracy: 89.56%
# For Task1 Epoch 4/5, Accuracy: 89.62%
# For Task1 Epoch 4/5, Accuracy: 89.61%
# For Task1 Epoch 4/5, Accuracy: 89.63%
# For Task1 Epoch 4/5, Accuracy: 89.62%
# For Task1 Epoch 4/5, Accuracy: 89.64%
# For Task1 Epoch 4/5, Accuracy: 89.63%
# For Task1 Epoch 4/5, Accuracy: 89.58%
# For Task1 Epoch 4/5, Accuracy: 89.61%
# For Task1 Epoch 4/5, Accuracy: 89.59%
# For Task1 Epoch 4/5, Accuracy: 89.65%
# For Task1 Epoch 4/5, Accuracy: 89.61%
# For Task1 Epoch 4/5, Accuracy: 89.59%
# For Task1 Epoch 4/5, Accuracy: 89.65%
# For Task1 Epoch 4/5, Accuracy: 89.64%
# For Task1 Epoch 4/5, Accuracy: 89.69%
# For Task1 Epoch 4/5, Accuracy: 89.71%
# For Task1 Epoch 4/5, Accuracy: 89.76%
# For Task1 Epoch 4/5, Accuracy: 89.82%
# For Task1 Epoch 4/5, Accuracy: 89.74%
# For Task1 Epoch 4/5, Accuracy: 89.70%
# For Task1 Epoch 4/5, Accuracy: 89.75%
# For Task1 Epoch 4/5, Accuracy: 89.71%
# For Task1 Epoch 4/5, Accuracy: 89.70%
# For Task1 Epoch 4/5, Accuracy: 89.69%
# For Task1 Epoch 4/5, Accuracy: 89.74%
# For Task1 Epoch 4/5, Accuracy: 89.63%
# For Task1 Epoch 4/5, Accuracy: 89.65%
# For Task1 Epoch 4/5, Accuracy: 89.67%
# For Task1 Epoch 4/5, Accuracy: 89.72%
# For Task1 Epoch 4/5, Accuracy: 89.74%
# For Task1 Epoch 4/5, Accuracy: 89.73%
# For Task1 Epoch 4/5, Accuracy: 89.66%
# For Task1 Epoch 4/5, Accuracy: 89.68%
# For Task1 Epoch 4/5, Accuracy: 89.70%
# For Task1 Epoch 4/5, Accuracy: 89.63%
# For Task1 Epoch 4/5, Accuracy: 89.65%
# For Task1 Epoch 4/5, Accuracy: 89.70%
# For Task1 Epoch 4/5, Accuracy: 89.72%
# For Task1 Epoch 4/5, Accuracy: 89.71%
# For Task1 Epoch 4/5, Accuracy: 89.75%
# For Task1 Epoch 4/5, Accuracy: 89.80%
# For Task1 Epoch 4/5, Accuracy: 89.79%
# For Task1 Epoch 4/5, Accuracy: 89.72%
# For Task1 Epoch 4/5, Accuracy: 89.71%
# For Task1 Epoch 4/5, Accuracy: 89.70%
# For Task1 Epoch 4/5, Accuracy: 89.72%
# For Task1 Epoch 4/5, Accuracy: 89.74%
# For Task1 Epoch 4/5, Accuracy: 89.76%
# For Task1 Epoch 4/5, Accuracy: 89.75%
# For Task1 Epoch 4/5, Accuracy: 89.79%
# For Task1 Epoch 4/5, Accuracy: 89.84%
# For Task1 Epoch 4/5, Accuracy: 89.83%
# For Task1 Epoch 4/5, Accuracy: 89.87%
# For Task1 Epoch 4/5, Accuracy: 89.81%
# For Task1 Epoch 4/5, Accuracy: 89.80%
# For Task1 Epoch 4/5, Accuracy: 89.84%
# For Task1 Epoch 4/5, Accuracy: 89.83%
# For Task1 Epoch 4/5, Accuracy: 89.79%
# For Task1 Epoch 4/5, Accuracy: 89.78%
# For Task1 Epoch 4/5, Accuracy: 89.83%
# For Task1 Epoch 4/5, Accuracy: 89.87%
# For Task1 Epoch 4/5, Accuracy: 89.89%
# For Task1 Epoch 4/5, Accuracy: 89.82%
# For Task1 Epoch 4/5, Accuracy: 89.76%
# For Task1 Epoch 4/5, Accuracy: 89.78%
# For Task1 Epoch 4/5, Accuracy: 89.80%
# For Task1 Epoch 4/5, Accuracy: 89.74%
# For Task1 Epoch 4/5, Accuracy: 89.78%
# For Task1 Epoch 4/5, Accuracy: 89.79%
# For Task1 Epoch 4/5, Accuracy: 89.83%
# For Task1 Epoch 4/5, Accuracy: 89.85%
# For Task1 Epoch 4/5, Accuracy: 89.84%
# For Task1 Epoch 4/5, Accuracy: 89.83%
# For Task1 Epoch 4/5, Accuracy: 89.85%
# For Task1 Epoch 4/5, Accuracy: 89.79%
# For Task1 Epoch 4/5, Accuracy: 89.83%
# For Task1 Epoch 4/5, Accuracy: 89.84%
# For Task1 Epoch 4/5, Accuracy: 89.81%
# For Task1 Epoch 4/5, Accuracy: 89.83%
# For Task1 Epoch 4/5, Accuracy: 89.84%
# For Task1 Epoch 4/5, Accuracy: 89.78%
# For Task1 Epoch 4/5, Accuracy: 89.82%
# For Task1 Epoch 4/5, Accuracy: 89.84%
# For Task1 Epoch 4/5, Accuracy: 89.85%
# For Task1 Epoch 4/5, Accuracy: 89.87%
# For Task1 Epoch 4/5, Accuracy: 89.86%
# For Task1 Epoch 4/5, Accuracy: 89.85%
# For Task1 Epoch 4/5, Accuracy: 89.86%
# For Task1 Epoch 4/5, Accuracy: 89.79%
# For Task1 Epoch 4/5, Accuracy: 89.80%
# For Task1 Epoch 4/5, Accuracy: 89.79%
# For Task1 Epoch 4/5, Accuracy: 89.78%
# For Task1 Epoch 4/5, Accuracy: 89.80%
# For Task1 Epoch 4/5, Accuracy: 89.77%
# For Task1 Epoch 4/5, Accuracy: 89.76%
# For Task1 Epoch 4/5, Accuracy: 89.80%
# For Task1 Epoch 4/5, Accuracy: 89.76%
# For Task1 Epoch 4/5, Accuracy: 89.73%
# For Task1 Epoch 4/5, Accuracy: 89.73%
# For Task1 Epoch 4/5, Accuracy: 89.72%
# For Task1 Epoch 4/5, Accuracy: 89.73%
# For Task1 Epoch 4/5, Accuracy: 89.75%
# For Task1 Epoch 4/5, Accuracy: 89.76%
# For Task1 Epoch 4/5, Accuracy: 89.75%
# For Task1 Epoch 4/5, Accuracy: 89.74%
# For Task1 Epoch 4/5, Accuracy: 89.74%
# For Task1 Epoch 4/5, Accuracy: 89.73%
# For Task1 Epoch 4/5, Accuracy: 89.74%
# For Task1 Epoch 4/5, Accuracy: 89.74%
# For Task1 Epoch 4/5, Accuracy: 89.73%
# For Task1 Epoch 4/5, Accuracy: 89.74%
# For Task1 Epoch 4/5, Accuracy: 89.73%
# For Task1 Epoch 4/5, Accuracy: 89.77%
# For Task1 Epoch 4/5, Accuracy: 89.76%
# For Task1 Epoch 4/5, Accuracy: 89.77%
# For Task1 Epoch 4/5, Accuracy: 89.79%
# For Task1 Epoch 4/5, Accuracy: 89.76%
# For Task1 Epoch 4/5, Accuracy: 89.75%
# For Task1 Epoch 4/5, Accuracy: 89.68%
# For Task1 Epoch 4/5, Accuracy: 89.69%
# For Task1 Epoch 4/5, Accuracy: 89.67%
# For Task1 Epoch 4/5, Accuracy: 89.64%
# For Task1 Epoch 4/5, Accuracy: 89.67%
# For Task1 Epoch 4/5, Accuracy: 89.65%
# For Task1 Epoch 4/5, Accuracy: 89.62%
# For Task1 Epoch 4/5, Accuracy: 89.59%
# For Task1 Epoch 4/5, Accuracy: 89.60%
# For Task1 Epoch 4/5, Accuracy: 89.64%
# For Task1 Epoch 4/5, Accuracy: 89.65%
# For Task1 Epoch 4/5, Accuracy: 89.64%
# For Task1 Epoch 4/5, Accuracy: 89.62%
# For Task1 Epoch 4/5, Accuracy: 89.63%
# For Task1 Epoch 4/5, Accuracy: 89.62%
# For Task1 Epoch 4/5, Accuracy: 89.60%
# For Task1 Epoch 5/5, Accuracy: 81.25%
# For Task1 Epoch 5/5, Accuracy: 78.12%
# For Task1 Epoch 5/5, Accuracy: 81.25%
# For Task1 Epoch 5/5, Accuracy: 81.25%
# For Task1 Epoch 5/5, Accuracy: 81.25%
# For Task1 Epoch 5/5, Accuracy: 82.29%
# For Task1 Epoch 5/5, Accuracy: 83.04%
# For Task1 Epoch 5/5, Accuracy: 83.59%
# For Task1 Epoch 5/5, Accuracy: 85.42%
# For Task1 Epoch 5/5, Accuracy: 85.62%
# ...
# For Task10 Epoch 4/5, Accuracy: 94.21%
# For Task10 Epoch 4/5, Accuracy: 94.18%
# For Task10 Epoch 4/5, Accuracy: 94.21%
# For Task10 Epoch 4/5, Accuracy: 94.23%
# For Task10 Epoch 4/5, Accuracy: 94.26%
# For Task10 Epoch 4/5, Accuracy: 94.23%
# For Task10 Epoch 4/5, Accuracy: 94.23%
# For Task10 Epoch 4/5, Accuracy: 94.25%
# For Task10 Epoch 4/5, Accuracy: 94.28%
# For Task10 Epoch 4/5, Accuracy: 94.28%
# For Task10 Epoch 4/5, Accuracy: 94.27%
# For Task10 Epoch 4/5, Accuracy: 94.24%
# For Task10 Epoch 4/5, Accuracy: 94.21%
# For Task10 Epoch 4/5, Accuracy: 94.21%
# For Task10 Epoch 4/5, Accuracy: 94.21%
# For Task10 Epoch 4/5, Accuracy: 94.23%
# For Task10 Epoch 4/5, Accuracy: 94.21%
# For Task10 Epoch 4/5, Accuracy: 94.18%
# For Task10 Epoch 4/5, Accuracy: 94.20%
# For Task10 Epoch 4/5, Accuracy: 94.17%
# For Task10 Epoch 4/5, Accuracy: 94.20%
# For Task10 Epoch 4/5, Accuracy: 94.17%
# For Task10 Epoch 4/5, Accuracy: 94.17%
# For Task10 Epoch 4/5, Accuracy: 94.17%
# For Task10 Epoch 4/5, Accuracy: 94.16%
# For Task10 Epoch 4/5, Accuracy: 94.16%
# For Task10 Epoch 4/5, Accuracy: 94.16%
# For Task10 Epoch 4/5, Accuracy: 94.19%
# For Task10 Epoch 4/5, Accuracy: 94.21%
# For Task10 Epoch 4/5, Accuracy: 94.23%
# For Task10 Epoch 4/5, Accuracy: 94.26%
# For Task10 Epoch 4/5, Accuracy: 94.28%
# For Task10 Epoch 4/5, Accuracy: 94.30%
# For Task10 Epoch 4/5, Accuracy: 94.33%
# For Task10 Epoch 4/5, Accuracy: 94.35%
# For Task10 Epoch 4/5, Accuracy: 94.35%
# For Task10 Epoch 4/5, Accuracy: 94.34%
# For Task10 Epoch 4/5, Accuracy: 94.37%
# For Task10 Epoch 4/5, Accuracy: 94.34%
# For Task10 Epoch 4/5, Accuracy: 94.34%
# For Task10 Epoch 4/5, Accuracy: 94.36%
# For Task10 Epoch 4/5, Accuracy: 94.38%
# For Task10 Epoch 4/5, Accuracy: 94.40%
# For Task10 Epoch 4/5, Accuracy: 94.38%
# For Task10 Epoch 4/5, Accuracy: 94.40%
# For Task10 Epoch 4/5, Accuracy: 94.39%
# For Task10 Epoch 4/5, Accuracy: 94.42%
# For Task10 Epoch 4/5, Accuracy: 94.41%
# For Task10 Epoch 4/5, Accuracy: 94.43%
# For Task10 Epoch 4/5, Accuracy: 94.45%
# For Task10 Epoch 4/5, Accuracy: 94.48%
# For Task10 Epoch 4/5, Accuracy: 94.47%
# For Task10 Epoch 4/5, Accuracy: 94.49%
# For Task10 Epoch 4/5, Accuracy: 94.44%
# For Task10 Epoch 4/5, Accuracy: 94.40%
# For Task10 Epoch 4/5, Accuracy: 94.39%
# For Task10 Epoch 4/5, Accuracy: 94.37%
# For Task10 Epoch 4/5, Accuracy: 94.39%
# For Task10 Epoch 4/5, Accuracy: 94.39%
# For Task10 Epoch 4/5, Accuracy: 94.38%
# For Task10 Epoch 4/5, Accuracy: 94.36%
# For Task10 Epoch 4/5, Accuracy: 94.38%
# For Task10 Epoch 4/5, Accuracy: 94.33%
# For Task10 Epoch 4/5, Accuracy: 94.35%
# For Task10 Epoch 4/5, Accuracy: 94.37%
# For Task10 Epoch 4/5, Accuracy: 94.37%
# For Task10 Epoch 4/5, Accuracy: 94.37%
# For Task10 Epoch 4/5, Accuracy: 94.30%
# For Task10 Epoch 4/5, Accuracy: 94.30%
# For Task10 Epoch 4/5, Accuracy: 94.23%
# For Task10 Epoch 4/5, Accuracy: 94.21%
# For Task10 Epoch 4/5, Accuracy: 94.21%
# For Task10 Epoch 4/5, Accuracy: 94.23%
# For Task10 Epoch 4/5, Accuracy: 94.25%
# For Task10 Epoch 4/5, Accuracy: 94.27%
# For Task10 Epoch 4/5, Accuracy: 94.24%
# For Task10 Epoch 4/5, Accuracy: 94.26%
# For Task10 Epoch 4/5, Accuracy: 94.28%
# For Task10 Epoch 4/5, Accuracy: 94.30%
# For Task10 Epoch 4/5, Accuracy: 94.32%
# For Task10 Epoch 4/5, Accuracy: 94.32%
# For Task10 Epoch 4/5, Accuracy: 94.34%
# For Task10 Epoch 4/5, Accuracy: 94.36%
# For Task10 Epoch 4/5, Accuracy: 94.33%
# For Task10 Epoch 4/5, Accuracy: 94.27%
# For Task10 Epoch 4/5, Accuracy: 94.29%
# For Task10 Epoch 4/5, Accuracy: 94.31%
# For Task10 Epoch 4/5, Accuracy: 94.28%
# For Task10 Epoch 4/5, Accuracy: 94.26%
# For Task10 Epoch 4/5, Accuracy: 94.28%
# For Task10 Epoch 4/5, Accuracy: 94.28%
# For Task10 Epoch 4/5, Accuracy: 94.28%
# For Task10 Epoch 4/5, Accuracy: 94.26%
# For Task10 Epoch 4/5, Accuracy: 94.27%
# For Task10 Epoch 4/5, Accuracy: 94.25%
# For Task10 Epoch 4/5, Accuracy: 94.25%
# For Task10 Epoch 4/5, Accuracy: 94.26%
# For Task10 Epoch 5/5, Accuracy: 100.00%
# For Task10 Epoch 5/5, Accuracy: 100.00%
# For Task10 Epoch 5/5, Accuracy: 95.83%
# For Task10 Epoch 5/5, Accuracy: 96.88%
# For Task10 Epoch 5/5, Accuracy: 93.75%
# For Task10 Epoch 5/5, Accuracy: 93.75%
# For Task10 Epoch 5/5, Accuracy: 94.64%
# For Task10 Epoch 5/5, Accuracy: 93.75%
# For Task10 Epoch 5/5, Accuracy: 94.44%
# For Task10 Epoch 5/5, Accuracy: 94.38%
# For Task10 Epoch 5/5, Accuracy: 94.89%
# For Task10 Epoch 5/5, Accuracy: 93.23%
# For Task10 Epoch 5/5, Accuracy: 93.75%
# For Task10 Epoch 5/5, Accuracy: 94.20%
# For Task10 Epoch 5/5, Accuracy: 94.17%
# For Task10 Epoch 5/5, Accuracy: 94.53%
# For Task10 Epoch 5/5, Accuracy: 94.12%
# For Task10 Epoch 5/5, Accuracy: 94.10%
# For Task10 Epoch 5/5, Accuracy: 93.42%
# For Task10 Epoch 5/5, Accuracy: 93.75%
# For Task10 Epoch 5/5, Accuracy: 93.75%
# For Task10 Epoch 5/5, Accuracy: 93.75%
# For Task10 Epoch 5/5, Accuracy: 93.48%
# For Task10 Epoch 5/5, Accuracy: 92.97%
# For Task10 Epoch 5/5, Accuracy: 92.75%
# For Task10 Epoch 5/5, Accuracy: 92.79%
# For Task10 Epoch 5/5, Accuracy: 93.06%
# For Task10 Epoch 5/5, Accuracy: 93.30%
# For Task10 Epoch 5/5, Accuracy: 93.53%
# For Task10 Epoch 5/5, Accuracy: 93.54%
# For Task10 Epoch 5/5, Accuracy: 93.75%
# For Task10 Epoch 5/5, Accuracy: 93.75%
# For Task10 Epoch 5/5, Accuracy: 93.94%
# For Task10 Epoch 5/5, Accuracy: 93.75%
# For Task10 Epoch 5/5, Accuracy: 93.93%
# For Task10 Epoch 5/5, Accuracy: 94.10%
# For Task10 Epoch 5/5, Accuracy: 94.26%
# For Task10 Epoch 5/5, Accuracy: 94.41%
# For Task10 Epoch 5/5, Accuracy: 94.55%
# For Task10 Epoch 5/5, Accuracy: 94.69%
# For Task10 Epoch 5/5, Accuracy: 94.66%
# For Task10 Epoch 5/5, Accuracy: 94.64%
# For Task10 Epoch 5/5, Accuracy: 94.62%
# For Task10 Epoch 5/5, Accuracy: 94.60%
# For Task10 Epoch 5/5, Accuracy: 94.72%
# For Task10 Epoch 5/5, Accuracy: 94.57%
# For Task10 Epoch 5/5, Accuracy: 94.41%
# For Task10 Epoch 5/5, Accuracy: 94.53%
# For Task10 Epoch 5/5, Accuracy: 94.52%
# For Task10 Epoch 5/5, Accuracy: 94.62%
# For Task10 Epoch 5/5, Accuracy: 94.61%
# For Task10 Epoch 5/5, Accuracy: 94.71%
# For Task10 Epoch 5/5, Accuracy: 94.81%
# For Task10 Epoch 5/5, Accuracy: 94.91%
# For Task10 Epoch 5/5, Accuracy: 95.00%
# For Task10 Epoch 5/5, Accuracy: 94.98%
# For Task10 Epoch 5/5, Accuracy: 95.07%
# For Task10 Epoch 5/5, Accuracy: 95.15%
# For Task10 Epoch 5/5, Accuracy: 95.23%
# For Task10 Epoch 5/5, Accuracy: 95.31%
# For Task10 Epoch 5/5, Accuracy: 95.18%
# For Task10 Epoch 5/5, Accuracy: 95.16%
# For Task10 Epoch 5/5, Accuracy: 95.04%
# For Task10 Epoch 5/5, Accuracy: 95.02%
# For Task10 Epoch 5/5, Accuracy: 95.00%
# For Task10 Epoch 5/5, Accuracy: 95.08%
# For Task10 Epoch 5/5, Accuracy: 95.15%
# For Task10 Epoch 5/5, Accuracy: 95.13%
# For Task10 Epoch 5/5, Accuracy: 95.20%
# For Task10 Epoch 5/5, Accuracy: 95.27%
# For Task10 Epoch 5/5, Accuracy: 95.33%
# For Task10 Epoch 5/5, Accuracy: 95.31%
# For Task10 Epoch 5/5, Accuracy: 95.38%
# For Task10 Epoch 5/5, Accuracy: 95.27%
# For Task10 Epoch 5/5, Accuracy: 95.33%
# For Task10 Epoch 5/5, Accuracy: 95.31%
# For Task10 Epoch 5/5, Accuracy: 95.37%
# For Task10 Epoch 5/5, Accuracy: 95.35%
# For Task10 Epoch 5/5, Accuracy: 95.41%
# For Task10 Epoch 5/5, Accuracy: 95.39%
# For Task10 Epoch 5/5, Accuracy: 95.45%
# For Task10 Epoch 5/5, Accuracy: 95.35%
# For Task10 Epoch 5/5, Accuracy: 95.33%
# For Task10 Epoch 5/5, Accuracy: 95.39%
# For Task10 Epoch 5/5, Accuracy: 95.37%
# For Task10 Epoch 5/5, Accuracy: 95.28%
# For Task10 Epoch 5/5, Accuracy: 95.11%
# For Task10 Epoch 5/5, Accuracy: 95.10%
# For Task10 Epoch 5/5, Accuracy: 95.08%
# For Task10 Epoch 5/5, Accuracy: 95.07%
# For Task10 Epoch 5/5, Accuracy: 95.12%
# For Task10 Epoch 5/5, Accuracy: 95.18%
# For Task10 Epoch 5/5, Accuracy: 95.09%
# For Task10 Epoch 5/5, Accuracy: 95.15%
# For Task10 Epoch 5/5, Accuracy: 95.07%
# For Task10 Epoch 5/5, Accuracy: 95.05%
# For Task10 Epoch 5/5, Accuracy: 95.04%
# For Task10 Epoch 5/5, Accuracy: 95.09%
# For Task10 Epoch 5/5, Accuracy: 95.08%
# For Task10 Epoch 5/5, Accuracy: 95.06%
# For Task10 Epoch 5/5, Accuracy: 95.11%
# For Task10 Epoch 5/5, Accuracy: 94.98%
# For Task10 Epoch 5/5, Accuracy: 94.90%
# For Task10 Epoch 5/5, Accuracy: 94.95%
# For Task10 Epoch 5/5, Accuracy: 94.94%
# For Task10 Epoch 5/5, Accuracy: 94.99%
# For Task10 Epoch 5/5, Accuracy: 94.92%
# For Task10 Epoch 5/5, Accuracy: 94.68%
# For Task10 Epoch 5/5, Accuracy: 94.72%
# For Task10 Epoch 5/5, Accuracy: 94.77%
# For Task10 Epoch 5/5, Accuracy: 94.71%
# For Task10 Epoch 5/5, Accuracy: 94.75%
# For Task10 Epoch 5/5, Accuracy: 94.80%
# For Task10 Epoch 5/5, Accuracy: 94.79%
# For Task10 Epoch 5/5, Accuracy: 94.84%
# For Task10 Epoch 5/5, Accuracy: 94.83%
# For Task10 Epoch 5/5, Accuracy: 94.87%
# For Task10 Epoch 5/5, Accuracy: 94.92%
# For Task10 Epoch 5/5, Accuracy: 94.91%
# For Task10 Epoch 5/5, Accuracy: 94.90%
# For Task10 Epoch 5/5, Accuracy: 94.89%
# For Task10 Epoch 5/5, Accuracy: 94.88%
# For Task10 Epoch 5/5, Accuracy: 94.87%
# For Task10 Epoch 5/5, Accuracy: 94.71%
# For Task10 Epoch 5/5, Accuracy: 94.70%
# For Task10 Epoch 5/5, Accuracy: 94.74%
# For Task10 Epoch 5/5, Accuracy: 94.78%
# For Task10 Epoch 5/5, Accuracy: 94.78%
# For Task10 Epoch 5/5, Accuracy: 94.82%
# For Task10 Epoch 5/5, Accuracy: 94.71%
# For Task10 Epoch 5/5, Accuracy: 94.66%
# For Task10 Epoch 5/5, Accuracy: 94.60%
# For Task10 Epoch 5/5, Accuracy: 94.50%
# For Task10 Epoch 5/5, Accuracy: 94.45%
# For Task10 Epoch 5/5, Accuracy: 94.49%
# For Task10 Epoch 5/5, Accuracy: 94.53%
# For Task10 Epoch 5/5, Accuracy: 94.57%
# For Task10 Epoch 5/5, Accuracy: 94.61%
# For Task10 Epoch 5/5, Accuracy: 94.65%
# For Task10 Epoch 5/5, Accuracy: 94.64%
# For Task10 Epoch 5/5, Accuracy: 94.55%
# For Task10 Epoch 5/5, Accuracy: 94.50%
# For Task10 Epoch 5/5, Accuracy: 94.45%
# For Task10 Epoch 5/5, Accuracy: 94.44%
# For Task10 Epoch 5/5, Accuracy: 94.44%
# For Task10 Epoch 5/5, Accuracy: 94.48%
# For Task10 Epoch 5/5, Accuracy: 94.47%
# For Task10 Epoch 5/5, Accuracy: 94.51%
# For Task10 Epoch 5/5, Accuracy: 94.51%
# For Task10 Epoch 5/5, Accuracy: 94.54%
# For Task10 Epoch 5/5, Accuracy: 94.50%
# For Task10 Epoch 5/5, Accuracy: 94.45%
# For Task10 Epoch 5/5, Accuracy: 94.40%
# For Task10 Epoch 5/5, Accuracy: 94.32%
# For Task10 Epoch 5/5, Accuracy: 94.35%
# For Task10 Epoch 5/5, Accuracy: 94.39%
# For Task10 Epoch 5/5, Accuracy: 94.31%
# For Task10 Epoch 5/5, Accuracy: 94.26%
# For Task10 Epoch 5/5, Accuracy: 94.26%
# For Task10 Epoch 5/5, Accuracy: 94.22%
# For Task10 Epoch 5/5, Accuracy: 94.14%
# For Task10 Epoch 5/5, Accuracy: 94.17%
# For Task10 Epoch 5/5, Accuracy: 94.13%
# For Task10 Epoch 5/5, Accuracy: 94.17%
# For Task10 Epoch 5/5, Accuracy: 94.17%
# For Task10 Epoch 5/5, Accuracy: 94.16%
# For Task10 Epoch 5/5, Accuracy: 94.20%
# For Task10 Epoch 5/5, Accuracy: 94.23%
# For Task10 Epoch 5/5, Accuracy: 94.23%
# For Task10 Epoch 5/5, Accuracy: 94.26%
# For Task10 Epoch 5/5, Accuracy: 94.26%
# For Task10 Epoch 5/5, Accuracy: 94.22%
# For Task10 Epoch 5/5, Accuracy: 94.08%
# For Task10 Epoch 5/5, Accuracy: 94.07%
# For Task10 Epoch 5/5, Accuracy: 94.07%
# For Task10 Epoch 5/5, Accuracy: 94.07%
# For Task10 Epoch 5/5, Accuracy: 94.07%
# For Task10 Epoch 5/5, Accuracy: 93.93%
# For Task10 Epoch 5/5, Accuracy: 93.92%
# For Task10 Epoch 5/5, Accuracy: 93.89%
# For Task10 Epoch 5/5, Accuracy: 93.89%
# For Task10 Epoch 5/5, Accuracy: 93.92%
# For Task10 Epoch 5/5, Accuracy: 93.95%
# For Task10 Epoch 5/5, Accuracy: 93.95%
# For Task10 Epoch 5/5, Accuracy: 93.99%
# For Task10 Epoch 5/5, Accuracy: 93.99%
# For Task10 Epoch 5/5, Accuracy: 93.95%
# For Task10 Epoch 5/5, Accuracy: 93.98%
# For Task10 Epoch 5/5, Accuracy: 93.98%
# For Task10 Epoch 5/5, Accuracy: 93.98%
# For Task10 Epoch 5/5, Accuracy: 93.91%
# For Task10 Epoch 5/5, Accuracy: 93.85%
# For Task10 Epoch 5/5, Accuracy: 93.85%
# For Task10 Epoch 5/5, Accuracy: 93.88%
# For Task10 Epoch 5/5, Accuracy: 93.85%
# For Task10 Epoch 5/5, Accuracy: 93.88%
# For Task10 Epoch 5/5, Accuracy: 93.85%
# For Task10 Epoch 5/5, Accuracy: 93.84%
# For Task10 Epoch 5/5, Accuracy: 93.84%
# For Task10 Epoch 5/5, Accuracy: 93.88%
# For Task10 Epoch 5/5, Accuracy: 93.87%
# For Task10 Epoch 5/5, Accuracy: 93.87%
# For Task10 Epoch 5/5, Accuracy: 93.81%
# For Task10 Epoch 5/5, Accuracy: 93.81%
# For Task10 Epoch 5/5, Accuracy: 93.84%
# For Task10 Epoch 5/5, Accuracy: 93.81%
# For Task10 Epoch 5/5, Accuracy: 93.78%
# For Task10 Epoch 5/5, Accuracy: 93.81%
# For Task10 Epoch 5/5, Accuracy: 93.84%
# For Task10 Epoch 5/5, Accuracy: 93.78%
# For Task10 Epoch 5/5, Accuracy: 93.75%
# For Task10 Epoch 5/5, Accuracy: 93.78%
# For Task10 Epoch 5/5, Accuracy: 93.78%
# For Task10 Epoch 5/5, Accuracy: 93.81%
# For Task10 Epoch 5/5, Accuracy: 93.84%
# For Task10 Epoch 5/5, Accuracy: 93.84%
# For Task10 Epoch 5/5, Accuracy: 93.84%
# For Task10 Epoch 5/5, Accuracy: 93.86%
# For Task10 Epoch 5/5, Accuracy: 93.84%
# For Task10 Epoch 5/5, Accuracy: 93.84%
# For Task10 Epoch 5/5, Accuracy: 93.83%
# For Task10 Epoch 5/5, Accuracy: 93.83%
# For Task10 Epoch 5/5, Accuracy: 93.86%
# For Task10 Epoch 5/5, Accuracy: 93.83%
# For Task10 Epoch 5/5, Accuracy: 93.86%
# For Task10 Epoch 5/5, Accuracy: 93.86%
# For Task10 Epoch 5/5, Accuracy: 93.89%
# For Task10 Epoch 5/5, Accuracy: 93.89%
# For Task10 Epoch 5/5, Accuracy: 93.83%
# For Task10 Epoch 5/5, Accuracy: 93.86%
# For Task10 Epoch 5/5, Accuracy: 93.86%
# For Task10 Epoch 5/5, Accuracy: 93.86%
# For Task10 Epoch 5/5, Accuracy: 93.86%
# For Task10 Epoch 5/5, Accuracy: 93.86%
# For Task10 Epoch 5/5, Accuracy: 93.86%
# For Task10 Epoch 5/5, Accuracy: 93.83%
# For Task10 Epoch 5/5, Accuracy: 93.80%
# For Task10 Epoch 5/5, Accuracy: 93.72%
# For Task10 Epoch 5/5, Accuracy: 93.72%
# For Task10 Epoch 5/5, Accuracy: 93.72%
# For Task10 Epoch 5/5, Accuracy: 93.72%
# For Task10 Epoch 5/5, Accuracy: 93.72%
# For Task10 Epoch 5/5, Accuracy: 93.70%
# For Task10 Epoch 5/5, Accuracy: 93.65%
# For Task10 Epoch 5/5, Accuracy: 93.62%
# For Task10 Epoch 5/5, Accuracy: 93.62%
# For Task10 Epoch 5/5, Accuracy: 93.62%
# For Task10 Epoch 5/5, Accuracy: 93.62%
# For Task10 Epoch 5/5, Accuracy: 93.60%
# For Task10 Epoch 5/5, Accuracy: 93.62%
# For Task10 Epoch 5/5, Accuracy: 93.63%
# For Task10 Epoch 5/5, Accuracy: 93.63%
# For Task10 Epoch 5/5, Accuracy: 93.65%
# For Task10 Epoch 5/5, Accuracy: 93.68%
# For Task10 Epoch 5/5, Accuracy: 93.65%
# For Task10 Epoch 5/5, Accuracy: 93.65%
# For Task10 Epoch 5/5, Accuracy: 93.68%
# For Task10 Epoch 5/5, Accuracy: 93.68%
# For Task10 Epoch 5/5, Accuracy: 93.70%
# For Task10 Epoch 5/5, Accuracy: 93.70%
# For Task10 Epoch 5/5, Accuracy: 93.73%
# For Task10 Epoch 5/5, Accuracy: 93.73%
# For Task10 Epoch 5/5, Accuracy: 93.75%
# For Task10 Epoch 5/5, Accuracy: 93.73%
# For Task10 Epoch 5/5, Accuracy: 93.73%
# For Task10 Epoch 5/5, Accuracy: 93.73%
# For Task10 Epoch 5/5, Accuracy: 93.75%
# For Task10 Epoch 5/5, Accuracy: 93.77%
# For Task10 Epoch 5/5, Accuracy: 93.73%
# For Task10 Epoch 5/5, Accuracy: 93.73%
# For Task10 Epoch 5/5, Accuracy: 93.70%
# For Task10 Epoch 5/5, Accuracy: 93.66%
# For Task10 Epoch 5/5, Accuracy: 93.64%
# For Task10 Epoch 5/5, Accuracy: 93.64%
# For Task10 Epoch 5/5, Accuracy: 93.59%
# For Task10 Epoch 5/5, Accuracy: 93.61%
# For Task10 Epoch 5/5, Accuracy: 93.64%
# For Task10 Epoch 5/5, Accuracy: 93.62%
# For Task10 Epoch 5/5, Accuracy: 93.62%
# For Task10 Epoch 5/5, Accuracy: 93.62%
# For Task10 Epoch 5/5, Accuracy: 93.59%
# For Task10 Epoch 5/5, Accuracy: 93.57%
# For Task10 Epoch 5/5, Accuracy: 93.57%
# For Task10 Epoch 5/5, Accuracy: 93.57%
# For Task10 Epoch 5/5, Accuracy: 93.60%
# For Task10 Epoch 5/5, Accuracy: 93.58%
# For Task10 Epoch 5/5, Accuracy: 93.60%
# For Task10 Epoch 5/5, Accuracy: 93.60%
# For Task10 Epoch 5/5, Accuracy: 93.62%
# For Task10 Epoch 5/5, Accuracy: 93.62%
# For Task10 Epoch 5/5, Accuracy: 93.64%
# For Task10 Epoch 5/5, Accuracy: 93.60%
# For Task10 Epoch 5/5, Accuracy: 93.60%
# For Task10 Epoch 5/5, Accuracy: 93.60%
# For Task10 Epoch 5/5, Accuracy: 93.62%
# For Task10 Epoch 5/5, Accuracy: 93.62%
# For Task10 Epoch 5/5, Accuracy: 93.64%
# For Task10 Epoch 5/5, Accuracy: 93.67%
# For Task10 Epoch 5/5, Accuracy: 93.69%
# For Task10 Epoch 5/5, Accuracy: 93.69%
# For Task10 Epoch 5/5, Accuracy: 93.71%
# For Task10 Epoch 5/5, Accuracy: 93.73%
# For Task10 Epoch 5/5, Accuracy: 93.71%
# For Task10 Epoch 5/5, Accuracy: 93.71%
# For Task10 Epoch 5/5, Accuracy: 93.69%
# For Task10 Epoch 5/5, Accuracy: 93.71%
# For Task10 Epoch 5/5, Accuracy: 93.73%
# For Task10 Epoch 5/5, Accuracy: 93.75%
# For Task10 Epoch 5/5, Accuracy: 93.73%
# For Task10 Epoch 5/5, Accuracy: 93.73%
# For Task10 Epoch 5/5, Accuracy: 93.75%
# For Task10 Epoch 5/5, Accuracy: 93.71%
# For Task10 Epoch 5/5, Accuracy: 93.72%

# %%
print('TESTING MODEL!!!')

model.eval()
with torch.no_grad():
    total_total = 0.0
    correct_total = 0.0

    for i in range(NUM_TASKS):
        dataloader = dataloaders_test[i]
        total_task = 0.0
        correct_task = 0.0

        for data in dataloader:
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            outputs, distance_sum = model(inputs)
            _, predicted = torch.max(outputs.data, 1)

            total_task += labels.size(0)
            correct_task += (predicted == labels).sum().item()

        
        print(f'For Task{i+1} Accuracy: {correct_task/total_task * 100:.2f}%')
        
        total_total += total_task
        correct_total += correct_task

    print(f'Overall Accuracy: {correct_total/total_total * 100:.2f}%')
# Out:
# TESTING MODEL!!!
# For Task1 Accuracy: 75.30%
# For Task2 Accuracy: 80.30%
# For Task3 Accuracy: 85.90%
# For Task4 Accuracy: 82.90%
# For Task5 Accuracy: 85.60%
# For Task6 Accuracy: 74.00%
# For Task7 Accuracy: 80.00%
# For Task8 Accuracy: 83.60%
# For Task9 Accuracy: 90.40%
# For Task10 Accuracy: 87.60%
# Overall Accuracy: 82.56%
